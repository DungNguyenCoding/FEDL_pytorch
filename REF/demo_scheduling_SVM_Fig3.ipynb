# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
# --- 1. Wireless Environment Parameters ---
B_HZ = 1e6              # 1 MHz
N0_DBM_HZ = -174        # Noise density
P_TX_CLIENT_DBM = 24    # Uplink Power
P_TX_SERVER_DBM = 46    # Downlink Power (Server)
Q_BITS = 16             # 16-bit quantization
RADIUS_KM = 0.5         # 500m
DEVICE_GFLOPS = 2.0     # Average edge device speed (2 Billion operations/sec)

# %%
# --- 2. Model Architectures ---

class SVMModel(nn.Module):
    def __init__(self):
        super(SVMModel, self).__init__()
        self.fc = nn.Linear(3072, 1)
    def forward(self, x):
        return self.fc(x.view(x.size(0), -1))

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, 5), nn.ReLU(), nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 5), nn.ReLU(), nn.MaxPool2d(2, 2)
        )
        self.fc = nn.Sequential(nn.Linear(64 * 4 * 4, 512), nn.ReLU(), nn.Linear(512, 10))
    def forward(self, x):
        x = self.conv(x)
        return self.fc(x.view(x.size(0), -1))

# %%
# --- 3. Wireless Channel ---

def get_round_delays(model, task):
    # --- 3.1. Wireless Environment Setup ---
    # Total Bandwidth B = 1MHz
    B_total = B_HZ 
    K = 30 # Number of devices
    
    # OFDMA Uplink: Each device gets a sub-channel Bk
    Bk = B_total / K 
    
    # Noise calculation (N0 * Bandwidth)
    # For Uplink: Noise power in sub-channel Bk
    noise_w_up = 10**(((N0_DBM_HZ + 10 * np.log10(Bk)) - 30) / 10)
    # For Downlink: Noise power in total bandwidth B
    noise_w_down = 10**(((N0_DBM_HZ + 10 * np.log10(B_total)) - 30) / 10)

    # Path Loss & Distances
    r_km = RADIUS_KM * np.sqrt(np.random.rand(K)) 
    path_loss_db = 128.1 + 37.6 * np.log10(np.maximum(r_km, 0.01))
    
    # Payload Size (N * q)
    num_params = sum(p.numel() for p in model.parameters())
    payload_bits = num_params * Q_BITS

    # --- 3.2. Downlink Calculation (Equation 5) ---
    # Downlink SNR (gamma) is determined by the device with the worst channel gain
    p_rx_dbm_down = P_TX_SERVER_DBM - path_loss_db
    p_rx_w_down = 10**((p_rx_dbm_down - 30) / 10)
    
    gamma_down = np.min(p_rx_w_down / noise_w_down) # Minimum SNR among devices
    r_downlink = B_total * np.log2(1 + gamma_down)  # Achievable rate r
    d_down = payload_bits / r_downlink

    # --- 3.3. Uplink Calculation (Equation 4) ---
    # Achievable rate r_k for each device k using sub-channel Bk
    p_rx_dbm_up = P_TX_CLIENT_DBM - path_loss_db
    p_rx_w_up = 10**((p_rx_dbm_up - 30) / 10)
    
    gamma_up = p_rx_w_up / noise_w_up         # SNR gamma_k for each device
    rk_uplink = Bk * np.log2(1 + gamma_up)    # Achievable rate r_k
    
    # Total Uplink delay is the time until the last device k finishes
    d_up = np.max(payload_bits / rk_uplink)

    # --- 3.4. Computation Delay ---
    flops_per_img = 6000 if task == 'SVM' else 15_000_000
    num_samples = 330 if task == 'SVM' else 2000
    t_comp = (num_samples * flops_per_img) / (DEVICE_GFLOPS * 1e9)

    return d_down, t_comp, d_up

# %%
# --- 4. Data Preparation ---

def get_datasets(task='CNN'):
    if task == 'SVM':
        transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
        train_set = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
        test_set = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
        
        # Filter classes 0 (airplane) and 1 (automobile)
        train_idx = [i for i, l in enumerate(train_set.targets) if l in [0, 1]]
        test_idx = [i for i, l in enumerate(test_set.targets) if l in [0, 1]]
        
        # 15 devices get only airplanes, 15 get only automobiles (330 samples each)
        airplanes = [i for i in train_idx if train_set.targets[i] == 0][:15*330]
        autos = [i for i in train_idx if train_set.targets[i] == 1][:15*330]
        
        device_data = [Subset(train_set, airplanes[i*330:(i+1)*330]) for i in range(15)] + \
                      [Subset(train_set, autos[i*330:(i+1)*330]) for i in range(15)]
        
        return device_data, Subset(test_set, test_idx), SVMModel(), 0.0001

    else: # CNN Task
        transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
        train_set = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
        test_set = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
        
        # Pathological Non-IID: Sort by label, 60 shards, 2 per client
        indices = np.argsort(train_set.targets.numpy())
        shards = [indices[i*1000 : (i+1)*1000] for i in range(60)]
        device_data = [Subset(train_set, np.concatenate((shards[i*2], shards[i*2+1]))) for i in range(30)]
        
        return device_data, test_set, CNNModel(), 0.005

# %%
def get_optimal_probabilities(n_k_list, grad_norms, T_u_list, rho):
    """
    Implements Theorem 1 with safeguards for baseline cases (rho=0 or 1).
    """
    n_total = sum(n_k_list)
    grad_norms = np.array(grad_norms) + 1e-12 
    T_u_list = np.array(T_u_list)

    # Shortcut for Channel-aware (rho=0) 
    if rho == 0:
        # Probability is inversely proportional to sqrt of latency
        p = 1.0 / np.sqrt(T_u_list + 1e-12)
        return p / np.sum(p)

    # Shortcut for Importance-aware (rho=1) [cite: 504]
    if rho == 1:
        # Probability is proportional to (n_k/n) * ||g_k||
        p = (np.array(n_k_list) / n_total) * grad_norms
        return p / np.sum(p)

    # Bisection search for Proposed Policy (0 < rho < 1) [cite: 322, 325]
    def compute_p_star(lam):
        denom = (1 - rho) * T_u_list + lam
        # Theorem 1: p_k is proportional to (n_k/n)*||g_k|| * sqrt(rho/denom)
        p = (np.array(n_k_list) / n_total) * grad_norms * np.sqrt(rho / np.maximum(denom, 1e-15))
        return p

    # Find search bounds for lambda
    # denom must be > 0, so lam > -(1-rho)*T_u_min
    low = -np.min((1 - rho) * T_u_list) + 1e-12
    high = 1e6
    
    for _ in range(100):
        mid = (low + high) / 2
        p_temp = compute_p_star(mid)
        if np.sum(p_temp) > 1:
            low = mid
        else:
            high = mid
            
    final_p = compute_p_star(high)
    return final_p / np.sum(final_p)

# %%
def run_importance_aware_fl(task='SVM', rounds=100, rho=5e-6):
    device_data, test_set, global_model, lr = get_datasets(task)
    test_loader = DataLoader(test_set, batch_size=1000, shuffle=False)
    n_k_list = [len(d) for d in device_data]
    n_total = sum(n_k_list)
    lmbda = 0.01 
    r_km = RADIUS_KM * np.sqrt(np.random.rand(30)) 
    
    history = {'acc': [], 'time': []}
    cumulative_time = 0

    print(f"\n--- Simulation: {task} | 30 Clients | {rounds} Rounds ---")

    for r in range(rounds):
        # Step 1: Wireless Environment
        path_loss_db = 128.1 + 37.6 * np.log10(np.maximum(r_km, 0.01))
        
        noise_up_w = 10**(((N0_DBM_HZ + 10 * np.log10(B_HZ)) - 30) / 10)
        p_rx_up_w = 10**(((P_TX_CLIENT_DBM - path_loss_db) - 30) / 10)
        gamma_up = p_rx_up_w / noise_up_w
        
        noise_down_w = 10**(((N0_DBM_HZ + 10 * np.log10(B_HZ)) - 30) / 10)
        p_rx_down_w = 10**(((P_TX_SERVER_DBM - path_loss_db) - 30) / 10)
        gamma_down_min = np.min(p_rx_down_w / noise_down_w) 
        
        num_params = sum(p.numel() for p in global_model.parameters())
        payload_bits = num_params * Q_BITS
        T_u_list = payload_bits / (B_HZ * np.log2(1 + gamma_up))

        # Steps 2 & 3: Importance Evaluation
        grad_norms = []
        client_gradients = []
        for i in range(30):
            local_model = type(global_model)()
            local_model.load_state_dict(global_model.state_dict())
            loader = DataLoader(device_data[i], batch_size=len(device_data[i]))
            data, target = next(iter(loader))
            local_model.zero_grad()
            output = local_model(data).squeeze()
            if task == 'SVM':
                target_svm = (target.float() * 2) - 1 
                loss = 0.5 * torch.mean(torch.clamp(1 - target_svm * output, min=0)) + (lmbda / 2.0) * sum(p.pow(2).sum() for p in local_model.parameters())
            else:
                target_oh = torch.nn.functional.one_hot(target, num_classes=10).float()
                loss = 0.5 * torch.nn.functional.mse_loss(output, target_oh, reduction='mean')
            loss.backward()
            grads = [p.grad.detach().clone() for p in local_model.parameters()]
            grad_norms.append(torch.norm(torch.cat([g.view(-1) for g in grads])).item())
            client_gradients.append(grads)

        # Step 4: Selection
        p_star = get_optimal_probabilities(n_k_list, grad_norms, T_u_list, rho)
        selected_idx = np.random.choice(range(30), p=p_star)

        # Step 5: Latency [cite: 279]
        t_broadcast = payload_bits / (B_HZ * np.log2(1 + gamma_down_min)) 
        t_comp_max = (max(n_k_list) * (6000 if task=='SVM' else 15e6)) / (DEVICE_GFLOPS * 1e9)
        cumulative_time += (t_broadcast + t_comp_max + T_u_list[selected_idx])

        # Step 6: Update [cite: 209]
        with torch.no_grad():
            scale = n_k_list[selected_idx] / (n_total * p_star[selected_idx])
            for p_global, g_local in zip(global_model.parameters(), client_gradients[selected_idx]):
                p_global -= lr * (scale * g_local)

        # Evaluation
        global_model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for data, target in test_loader:
                output = global_model(data)
                pred = torch.sign(output.squeeze()) if task == 'SVM' else output.argmax(1)
                labels = (target.float()*2-1) if task == 'SVM' else target
                correct += (pred == labels).sum().item()
                total += target.size(0)
        
        acc = 100. * correct / total
        history['acc'].append(acc)
        history['time'].append(cumulative_time)
        print(f"Round {r+1:02d} | Acc: {acc:.2f}% | Sim Time: {cumulative_time:.2f}s")

    return history

# %%
def run_full_comparison(task='SVM', rounds=50):
    """
    Executes all scheduling policies for a specific task and plots the results.
    """
    # Set default rounds and rhos based on the paper's experiment settings
    if task == 'SVM':
        # Paper uses these rho values for SVM comparison [cite: 507]
        rhos = {0: 'Channel-aware', 
                1: 'Importance-aware', 
                5e-6: 'Proposed (5e-6)', 
                5e-4: 'Proposed (5e-4)'}
        x_label = "Training Time (seconds)"
        time_scale = 1 # Seconds
    else: # CNN
        # Paper uses these rho values for CNN comparison [cite: 590]
        rhos = {0: 'Channel-aware', 
                1: 'Importance-aware', 
                5e-3: 'Proposed (5e-3)'}
        x_label = "Training Time (minutes)"
        time_scale = 60 # Minutes
    
    results = {}
    
    print(f"--- Starting {task} Comparison for {rounds} Rounds ---")
    for rho, label in rhos.items():
        print(f"Running {label} (rho={rho})...")
        # Ensure your model/optimizer is reset inside run_importance_aware_fl for each policy
        results[label] = run_importance_aware_fl(task=task, rounds=rounds, rho=rho)

    # --- Plotting ---
    plt.figure(figsize=(10, 6))
    for label, hist in results.items():
        # Convert time to the appropriate scale (seconds or minutes) [cite: 592]
        plt.plot(np.array(hist['time']) / time_scale, hist['acc'], label=label)
    
    plt.title(f"Performance Comparison: {task} Model")
    plt.xlabel(x_label)
    plt.ylabel("Test Accuracy")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# To run SVM comparison:
# run_full_comparison(task='SVM')

# To run CNN comparison:
# run_full_comparison(task='CNN')

# %%
run_importance_aware_fl(task='SVM', rounds=10, rho = 0)
# Out:
# c:\Users\aloti\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# --- Simulation: SVM | 30 Clients | 10 Rounds ---
# Round 01 | Acc: 46.75% | Sim Time: 0.01s
# Round 02 | Acc: 47.40% | Sim Time: 0.02s
# Round 03 | Acc: 48.05% | Sim Time: 0.03s
# Round 04 | Acc: 48.35% | Sim Time: 0.04s
# Round 05 | Acc: 48.90% | Sim Time: 0.05s
# Round 06 | Acc: 49.00% | Sim Time: 0.06s
# Round 07 | Acc: 49.95% | Sim Time: 0.07s
# Round 08 | Acc: 50.70% | Sim Time: 0.08s
# Round 09 | Acc: 50.80% | Sim Time: 0.09s
# Round 10 | Acc: 50.80% | Sim Time: 0.10s
# {'acc': [46.75, 47.4, 48.05, 48.35, 48.9, 49.0, 49.95, 50.7, 50.8, 50.8],
#  'time': [np.float64(0.00987558534661378),
#   np.float64(0.01891889741550931),
#   np.float64(0.027376032312122184),
#   np.float64(0.037629551642693826),
#   np.float64(0.04775027936740443),
#   np.float64(0.056207414264017305),
#   np.float64(0.06710779719519158),
#   np.float64(0.07787746717276588),
#   np.float64(0.08813098650333752),
#   np.float64(0.09798098685463347)]}

# %%
run_full_comparison(task='SVM', rounds=12000)
# Out:
# --- Starting SVM Comparison for 12000 Rounds ---
# Running Channel-aware (rho=0)...
#
# --- Simulation: SVM | 30 Clients | 12000 Rounds ---
# Round 01 | Acc: 35.60% | Sim Time: 0.01s
# Round 02 | Acc: 35.75% | Sim Time: 0.02s
# Round 03 | Acc: 35.80% | Sim Time: 0.03s
# Round 04 | Acc: 35.90% | Sim Time: 0.04s
# Round 05 | Acc: 36.30% | Sim Time: 0.05s
# Round 06 | Acc: 36.25% | Sim Time: 0.06s
# Round 07 | Acc: 36.50% | Sim Time: 0.07s
# Round 08 | Acc: 36.55% | Sim Time: 0.08s
# Round 09 | Acc: 36.60% | Sim Time: 0.09s
# Round 10 | Acc: 36.45% | Sim Time: 0.10s
# Round 11 | Acc: 36.90% | Sim Time: 0.11s
# Round 12 | Acc: 37.05% | Sim Time: 0.12s
# Round 13 | Acc: 37.30% | Sim Time: 0.13s
# Round 14 | Acc: 37.75% | Sim Time: 0.14s
# Round 15 | Acc: 38.00% | Sim Time: 0.15s
# Round 16 | Acc: 38.20% | Sim Time: 0.16s
# Round 17 | Acc: 38.35% | Sim Time: 0.16s
# Round 18 | Acc: 38.40% | Sim Time: 0.17s
# Round 19 | Acc: 38.75% | Sim Time: 0.18s
# Round 20 | Acc: 38.85% | Sim Time: 0.19s
# Round 21 | Acc: 39.05% | Sim Time: 0.20s
# Round 22 | Acc: 39.45% | Sim Time: 0.21s
# Round 23 | Acc: 40.00% | Sim Time: 0.22s
# Round 24 | Acc: 40.70% | Sim Time: 0.23s
# Round 25 | Acc: 40.95% | Sim Time: 0.23s
# Round 26 | Acc: 41.10% | Sim Time: 0.24s
# Round 27 | Acc: 41.45% | Sim Time: 0.25s
# Round 28 | Acc: 41.90% | Sim Time: 0.27s
# Round 29 | Acc: 42.50% | Sim Time: 0.27s
# Round 30 | Acc: 43.10% | Sim Time: 0.29s
# Round 31 | Acc: 43.50% | Sim Time: 0.30s
# Round 32 | Acc: 43.85% | Sim Time: 0.31s
# Round 33 | Acc: 44.40% | Sim Time: 0.32s
# Round 34 | Acc: 44.85% | Sim Time: 0.33s
# Round 35 | Acc: 45.10% | Sim Time: 0.34s
# Round 36 | Acc: 45.40% | Sim Time: 0.34s
# Round 37 | Acc: 46.25% | Sim Time: 0.35s
# Round 38 | Acc: 46.65% | Sim Time: 0.36s
# Round 39 | Acc: 47.15% | Sim Time: 0.37s
# Round 40 | Acc: 47.35% | Sim Time: 0.38s
# Round 41 | Acc: 47.85% | Sim Time: 0.39s
# Round 42 | Acc: 48.35% | Sim Time: 0.40s
# Round 43 | Acc: 48.55% | Sim Time: 0.41s
# Round 44 | Acc: 49.25% | Sim Time: 0.42s
# Round 45 | Acc: 49.65% | Sim Time: 0.43s
# Round 46 | Acc: 49.90% | Sim Time: 0.43s
# Round 47 | Acc: 50.55% | Sim Time: 0.44s
# Round 48 | Acc: 51.15% | Sim Time: 0.45s
# Round 49 | Acc: 51.50% | Sim Time: 0.46s
# Round 50 | Acc: 51.60% | Sim Time: 0.47s
# Round 51 | Acc: 52.00% | Sim Time: 0.48s
# Round 52 | Acc: 52.30% | Sim Time: 0.49s
# Round 53 | Acc: 52.85% | Sim Time: 0.50s
# Round 54 | Acc: 53.45% | Sim Time: 0.51s
# Round 55 | Acc: 53.75% | Sim Time: 0.52s
# Round 56 | Acc: 53.80% | Sim Time: 0.53s
# Round 57 | Acc: 54.15% | Sim Time: 0.54s
# Round 58 | Acc: 54.50% | Sim Time: 0.55s
# Round 59 | Acc: 54.70% | Sim Time: 0.56s
# Round 60 | Acc: 55.25% | Sim Time: 0.57s
# Round 61 | Acc: 55.35% | Sim Time: 0.58s
# Round 62 | Acc: 55.65% | Sim Time: 0.59s
# Round 63 | Acc: 56.45% | Sim Time: 0.60s
# Round 64 | Acc: 57.20% | Sim Time: 0.61s
# Round 65 | Acc: 57.55% | Sim Time: 0.62s
# Round 66 | Acc: 57.60% | Sim Time: 0.63s
# Round 67 | Acc: 58.20% | Sim Time: 0.64s
# Round 68 | Acc: 58.30% | Sim Time: 0.65s
# Round 69 | Acc: 59.25% | Sim Time: 0.66s
# Round 70 | Acc: 59.25% | Sim Time: 0.67s
# Round 71 | Acc: 59.55% | Sim Time: 0.69s
# Round 72 | Acc: 59.65% | Sim Time: 0.69s
# Round 73 | Acc: 60.15% | Sim Time: 0.70s
# Round 74 | Acc: 60.45% | Sim Time: 0.71s
# Round 75 | Acc: 60.65% | Sim Time: 0.72s
# Round 76 | Acc: 61.15% | Sim Time: 0.73s
# Round 77 | Acc: 61.70% | Sim Time: 0.74s
# Round 78 | Acc: 61.85% | Sim Time: 0.75s
# Round 79 | Acc: 62.20% | Sim Time: 0.76s
# Round 80 | Acc: 62.25% | Sim Time: 0.77s
# Round 81 | Acc: 62.20% | Sim Time: 0.78s
# Round 82 | Acc: 62.40% | Sim Time: 0.80s
# Round 83 | Acc: 62.65% | Sim Time: 0.80s
# Round 84 | Acc: 62.85% | Sim Time: 0.81s
# Round 85 | Acc: 62.85% | Sim Time: 0.83s
# Round 86 | Acc: 63.10% | Sim Time: 0.84s
# Round 87 | Acc: 63.30% | Sim Time: 0.85s
# Round 88 | Acc: 63.50% | Sim Time: 0.85s
# Round 89 | Acc: 63.65% | Sim Time: 0.86s
# Round 90 | Acc: 64.00% | Sim Time: 0.87s
# Round 91 | Acc: 64.00% | Sim Time: 0.89s
# Round 92 | Acc: 64.10% | Sim Time: 0.89s
# Round 93 | Acc: 64.15% | Sim Time: 0.90s
# Round 94 | Acc: 64.20% | Sim Time: 0.91s
# Round 95 | Acc: 64.20% | Sim Time: 0.92s
# Round 96 | Acc: 64.25% | Sim Time: 0.93s
# Round 97 | Acc: 64.55% | Sim Time: 0.93s
# Round 98 | Acc: 64.55% | Sim Time: 0.94s
# Round 99 | Acc: 64.75% | Sim Time: 0.95s
# Round 100 | Acc: 65.00% | Sim Time: 0.96s
# Round 101 | Acc: 65.05% | Sim Time: 0.97s
# Round 102 | Acc: 65.20% | Sim Time: 0.98s
# Round 103 | Acc: 65.40% | Sim Time: 0.99s
# Round 104 | Acc: 65.05% | Sim Time: 1.00s
# Round 105 | Acc: 64.95% | Sim Time: 1.01s
# Round 106 | Acc: 64.90% | Sim Time: 1.02s
# Round 107 | Acc: 65.25% | Sim Time: 1.03s
# Round 108 | Acc: 65.25% | Sim Time: 1.04s
# Round 109 | Acc: 65.35% | Sim Time: 1.05s
# Round 110 | Acc: 65.25% | Sim Time: 1.06s
# Round 111 | Acc: 65.45% | Sim Time: 1.07s
# Round 112 | Acc: 65.50% | Sim Time: 1.08s
# Round 113 | Acc: 65.70% | Sim Time: 1.09s
# Round 114 | Acc: 65.70% | Sim Time: 1.10s
# Round 115 | Acc: 65.90% | Sim Time: 1.11s
# Round 116 | Acc: 65.90% | Sim Time: 1.11s
# Round 117 | Acc: 66.05% | Sim Time: 1.13s
# Round 118 | Acc: 66.00% | Sim Time: 1.13s
# Round 119 | Acc: 66.00% | Sim Time: 1.14s
# Round 120 | Acc: 66.00% | Sim Time: 1.15s
# Round 121 | Acc: 66.00% | Sim Time: 1.16s
# Round 122 | Acc: 66.05% | Sim Time: 1.17s
# Round 123 | Acc: 66.25% | Sim Time: 1.18s
# Round 124 | Acc: 66.15% | Sim Time: 1.19s
# Round 125 | Acc: 66.20% | Sim Time: 1.19s
# Round 126 | Acc: 66.30% | Sim Time: 1.20s
# Round 127 | Acc: 66.25% | Sim Time: 1.21s
# Round 128 | Acc: 66.35% | Sim Time: 1.22s
# Round 129 | Acc: 66.30% | Sim Time: 1.22s
# Round 130 | Acc: 66.45% | Sim Time: 1.23s
# Round 131 | Acc: 66.55% | Sim Time: 1.24s
# Round 132 | Acc: 66.80% | Sim Time: 1.25s
# Round 133 | Acc: 66.80% | Sim Time: 1.27s
# Round 134 | Acc: 67.00% | Sim Time: 1.28s
# Round 135 | Acc: 66.85% | Sim Time: 1.29s
# Round 136 | Acc: 66.90% | Sim Time: 1.29s
# Round 137 | Acc: 67.05% | Sim Time: 1.30s
# Round 138 | Acc: 67.25% | Sim Time: 1.31s
# Round 139 | Acc: 67.25% | Sim Time: 1.32s
# Round 140 | Acc: 67.50% | Sim Time: 1.33s
# Round 141 | Acc: 67.70% | Sim Time: 1.34s
# Round 142 | Acc: 67.55% | Sim Time: 1.35s
# Round 143 | Acc: 67.45% | Sim Time: 1.36s
# Round 144 | Acc: 67.45% | Sim Time: 1.37s
# Round 145 | Acc: 67.45% | Sim Time: 1.38s
# Round 146 | Acc: 67.45% | Sim Time: 1.39s
# Round 147 | Acc: 67.45% | Sim Time: 1.40s
# Round 148 | Acc: 67.35% | Sim Time: 1.41s
# Round 149 | Acc: 67.30% | Sim Time: 1.42s
# Round 150 | Acc: 67.40% | Sim Time: 1.42s
# Round 151 | Acc: 67.55% | Sim Time: 1.44s
# Round 152 | Acc: 67.65% | Sim Time: 1.45s
# Round 153 | Acc: 67.65% | Sim Time: 1.45s
# Round 154 | Acc: 67.75% | Sim Time: 1.46s
# Round 155 | Acc: 67.80% | Sim Time: 1.47s
# Round 156 | Acc: 67.85% | Sim Time: 1.48s
# Round 157 | Acc: 67.80% | Sim Time: 1.49s
# Round 158 | Acc: 67.80% | Sim Time: 1.50s
# Round 159 | Acc: 68.00% | Sim Time: 1.51s
# Round 160 | Acc: 67.95% | Sim Time: 1.52s
# Round 161 | Acc: 67.85% | Sim Time: 1.52s
# Round 162 | Acc: 67.95% | Sim Time: 1.53s
# Round 163 | Acc: 67.90% | Sim Time: 1.54s
# Round 164 | Acc: 67.90% | Sim Time: 1.55s
# Round 165 | Acc: 68.10% | Sim Time: 1.56s
# Round 166 | Acc: 68.10% | Sim Time: 1.57s
# Round 167 | Acc: 68.05% | Sim Time: 1.59s
# Round 168 | Acc: 68.00% | Sim Time: 1.59s
# Round 169 | Acc: 68.05% | Sim Time: 1.60s
# Round 170 | Acc: 68.10% | Sim Time: 1.61s
# Round 171 | Acc: 68.00% | Sim Time: 1.62s
# Round 172 | Acc: 68.25% | Sim Time: 1.63s
# Round 173 | Acc: 68.20% | Sim Time: 1.64s
# Round 174 | Acc: 68.15% | Sim Time: 1.65s
# Round 175 | Acc: 68.40% | Sim Time: 1.66s
# Round 176 | Acc: 68.30% | Sim Time: 1.67s
# Round 177 | Acc: 68.30% | Sim Time: 1.68s
# Round 178 | Acc: 68.30% | Sim Time: 1.69s
# Round 179 | Acc: 68.35% | Sim Time: 1.70s
# Round 180 | Acc: 68.35% | Sim Time: 1.71s
# Round 181 | Acc: 68.35% | Sim Time: 1.71s
# Round 182 | Acc: 68.50% | Sim Time: 1.72s
# Round 183 | Acc: 68.65% | Sim Time: 1.73s
# Round 184 | Acc: 68.65% | Sim Time: 1.74s
# Round 185 | Acc: 68.65% | Sim Time: 1.75s
# Round 186 | Acc: 68.70% | Sim Time: 1.76s
# Round 187 | Acc: 68.70% | Sim Time: 1.77s
# Round 188 | Acc: 68.65% | Sim Time: 1.78s
# Round 189 | Acc: 68.50% | Sim Time: 1.79s
# Round 190 | Acc: 68.70% | Sim Time: 1.80s
# Round 191 | Acc: 68.85% | Sim Time: 1.81s
# Round 192 | Acc: 69.00% | Sim Time: 1.82s
# Round 193 | Acc: 68.95% | Sim Time: 1.83s
# Round 194 | Acc: 68.90% | Sim Time: 1.84s
# Round 195 | Acc: 68.90% | Sim Time: 1.85s
# Round 196 | Acc: 68.95% | Sim Time: 1.86s
# Round 197 | Acc: 68.95% | Sim Time: 1.87s
# Round 198 | Acc: 68.95% | Sim Time: 1.88s
# Round 199 | Acc: 69.15% | Sim Time: 1.89s
# Round 200 | Acc: 69.15% | Sim Time: 1.89s
# Round 201 | Acc: 69.25% | Sim Time: 1.90s
# Round 202 | Acc: 69.45% | Sim Time: 1.91s
# Round 203 | Acc: 69.30% | Sim Time: 1.92s
# Round 204 | Acc: 69.30% | Sim Time: 1.93s
# Round 205 | Acc: 69.35% | Sim Time: 1.94s
# Round 206 | Acc: 69.45% | Sim Time: 1.95s
# Round 207 | Acc: 69.45% | Sim Time: 1.96s
# Round 208 | Acc: 69.45% | Sim Time: 1.97s
# Round 209 | Acc: 69.65% | Sim Time: 1.98s
# Round 210 | Acc: 69.55% | Sim Time: 1.99s
# Round 211 | Acc: 69.50% | Sim Time: 2.00s
# Round 212 | Acc: 69.55% | Sim Time: 2.00s
# Round 213 | Acc: 69.55% | Sim Time: 2.01s
# Round 214 | Acc: 69.45% | Sim Time: 2.02s
# Round 215 | Acc: 69.60% | Sim Time: 2.03s
# Round 216 | Acc: 69.65% | Sim Time: 2.04s
# Round 217 | Acc: 69.60% | Sim Time: 2.05s
# Round 218 | Acc: 69.75% | Sim Time: 2.06s
# Round 219 | Acc: 69.75% | Sim Time: 2.07s
# Round 220 | Acc: 69.90% | Sim Time: 2.08s
# Round 221 | Acc: 69.95% | Sim Time: 2.09s
# Round 222 | Acc: 70.10% | Sim Time: 2.10s
# Round 223 | Acc: 70.15% | Sim Time: 2.11s
# Round 224 | Acc: 70.30% | Sim Time: 2.13s
# Round 225 | Acc: 70.25% | Sim Time: 2.14s
# Round 226 | Acc: 70.15% | Sim Time: 2.15s
# Round 227 | Acc: 70.10% | Sim Time: 2.16s
# Round 228 | Acc: 70.10% | Sim Time: 2.17s
# Round 229 | Acc: 70.15% | Sim Time: 2.18s
# Round 230 | Acc: 70.10% | Sim Time: 2.19s
# Round 231 | Acc: 70.15% | Sim Time: 2.19s
# Round 232 | Acc: 70.30% | Sim Time: 2.21s
# Round 233 | Acc: 70.25% | Sim Time: 2.22s
# Round 234 | Acc: 70.25% | Sim Time: 2.23s
# Round 235 | Acc: 70.35% | Sim Time: 2.24s
# Round 236 | Acc: 70.30% | Sim Time: 2.25s
# Round 237 | Acc: 70.30% | Sim Time: 2.26s
# Round 238 | Acc: 70.25% | Sim Time: 2.27s
# Round 239 | Acc: 70.15% | Sim Time: 2.28s
# Round 240 | Acc: 70.30% | Sim Time: 2.29s
# Round 241 | Acc: 70.15% | Sim Time: 2.30s
# Round 242 | Acc: 70.30% | Sim Time: 2.31s
# Round 243 | Acc: 70.45% | Sim Time: 2.32s
# Round 244 | Acc: 70.35% | Sim Time: 2.33s
# Round 245 | Acc: 70.25% | Sim Time: 2.34s
# Round 246 | Acc: 70.20% | Sim Time: 2.35s
# Round 247 | Acc: 70.15% | Sim Time: 2.36s
# Round 248 | Acc: 70.30% | Sim Time: 2.37s
# Round 249 | Acc: 70.15% | Sim Time: 2.38s
# Round 250 | Acc: 70.15% | Sim Time: 2.39s
# Round 251 | Acc: 70.20% | Sim Time: 2.40s
# Round 252 | Acc: 70.20% | Sim Time: 2.41s
# Round 253 | Acc: 70.15% | Sim Time: 2.42s
# Round 254 | Acc: 70.20% | Sim Time: 2.43s
# Round 255 | Acc: 70.20% | Sim Time: 2.44s
# Round 256 | Acc: 70.20% | Sim Time: 2.45s
# Round 257 | Acc: 70.25% | Sim Time: 2.46s
# Round 258 | Acc: 70.20% | Sim Time: 2.46s
# Round 259 | Acc: 70.35% | Sim Time: 2.47s
# Round 260 | Acc: 70.25% | Sim Time: 2.48s
# Round 261 | Acc: 70.30% | Sim Time: 2.49s
# Round 262 | Acc: 70.25% | Sim Time: 2.50s
# Round 263 | Acc: 70.40% | Sim Time: 2.51s
# Round 264 | Acc: 70.30% | Sim Time: 2.52s
# Round 265 | Acc: 70.30% | Sim Time: 2.53s
# Round 266 | Acc: 70.50% | Sim Time: 2.54s
# Round 267 | Acc: 70.40% | Sim Time: 2.55s
# Round 268 | Acc: 70.45% | Sim Time: 2.56s
# Round 269 | Acc: 70.40% | Sim Time: 2.57s
# Round 270 | Acc: 70.35% | Sim Time: 2.58s
# Round 271 | Acc: 70.45% | Sim Time: 2.59s
# Round 272 | Acc: 70.45% | Sim Time: 2.60s
# Round 273 | Acc: 70.35% | Sim Time: 2.61s
# Round 274 | Acc: 70.45% | Sim Time: 2.62s
# Round 275 | Acc: 70.50% | Sim Time: 2.63s
# Round 276 | Acc: 70.45% | Sim Time: 2.64s
# Round 277 | Acc: 70.55% | Sim Time: 2.66s
# Round 278 | Acc: 70.55% | Sim Time: 2.66s
# Round 279 | Acc: 70.55% | Sim Time: 2.67s
# Round 280 | Acc: 70.55% | Sim Time: 2.68s
# Round 281 | Acc: 70.50% | Sim Time: 2.69s
# Round 282 | Acc: 70.45% | Sim Time: 2.70s
# Round 283 | Acc: 70.45% | Sim Time: 2.71s
# Round 284 | Acc: 70.55% | Sim Time: 2.72s
# Round 285 | Acc: 70.60% | Sim Time: 2.73s
# Round 286 | Acc: 70.60% | Sim Time: 2.73s
# Round 287 | Acc: 70.60% | Sim Time: 2.74s
# Round 288 | Acc: 70.50% | Sim Time: 2.75s
# Round 289 | Acc: 70.60% | Sim Time: 2.76s
# Round 290 | Acc: 70.60% | Sim Time: 2.77s
# Round 291 | Acc: 70.75% | Sim Time: 2.78s
# Round 292 | Acc: 70.75% | Sim Time: 2.79s
# Round 293 | Acc: 70.65% | Sim Time: 2.80s
# Round 294 | Acc: 70.80% | Sim Time: 2.81s
# Round 295 | Acc: 70.80% | Sim Time: 2.82s
# Round 296 | Acc: 70.70% | Sim Time: 2.83s
# Round 297 | Acc: 70.80% | Sim Time: 2.84s
# Round 298 | Acc: 70.75% | Sim Time: 2.85s
# Round 299 | Acc: 70.85% | Sim Time: 2.86s
# Round 300 | Acc: 71.15% | Sim Time: 2.87s
# Round 301 | Acc: 71.25% | Sim Time: 2.88s
# Round 302 | Acc: 71.20% | Sim Time: 2.89s
# Round 303 | Acc: 71.10% | Sim Time: 2.90s
# Round 304 | Acc: 71.30% | Sim Time: 2.91s
# Round 305 | Acc: 71.25% | Sim Time: 2.92s
# Round 306 | Acc: 71.20% | Sim Time: 2.93s
# Round 307 | Acc: 71.30% | Sim Time: 2.94s
# Round 308 | Acc: 71.30% | Sim Time: 2.95s
# Round 309 | Acc: 71.35% | Sim Time: 2.96s
# Round 310 | Acc: 71.40% | Sim Time: 2.97s
# Round 311 | Acc: 71.40% | Sim Time: 2.98s
# Round 312 | Acc: 71.35% | Sim Time: 2.99s
# Round 313 | Acc: 71.40% | Sim Time: 3.00s
# Round 314 | Acc: 71.40% | Sim Time: 3.01s
# Round 315 | Acc: 71.45% | Sim Time: 3.01s
# Round 316 | Acc: 71.45% | Sim Time: 3.02s
# Round 317 | Acc: 71.45% | Sim Time: 3.03s
# Round 318 | Acc: 71.55% | Sim Time: 3.04s
# Round 319 | Acc: 71.75% | Sim Time: 3.05s
# Round 320 | Acc: 71.60% | Sim Time: 3.06s
# Round 321 | Acc: 71.80% | Sim Time: 3.07s
# Round 322 | Acc: 71.85% | Sim Time: 3.08s
# Round 323 | Acc: 71.80% | Sim Time: 3.09s
# Round 324 | Acc: 71.80% | Sim Time: 3.10s
# Round 325 | Acc: 71.80% | Sim Time: 3.11s
# Round 326 | Acc: 71.80% | Sim Time: 3.12s
# Round 327 | Acc: 71.80% | Sim Time: 3.13s
# Round 328 | Acc: 71.75% | Sim Time: 3.14s
# Round 329 | Acc: 71.85% | Sim Time: 3.15s
# Round 330 | Acc: 71.80% | Sim Time: 3.16s
# Round 331 | Acc: 71.80% | Sim Time: 3.17s
# Round 332 | Acc: 71.90% | Sim Time: 3.18s
# Round 333 | Acc: 71.90% | Sim Time: 3.19s
# Round 334 | Acc: 71.95% | Sim Time: 3.20s
# Round 335 | Acc: 71.95% | Sim Time: 3.21s
# Round 336 | Acc: 71.95% | Sim Time: 3.22s
# Round 337 | Acc: 71.90% | Sim Time: 3.23s
# Round 338 | Acc: 71.95% | Sim Time: 3.24s
# Round 339 | Acc: 72.00% | Sim Time: 3.24s
# Round 340 | Acc: 71.95% | Sim Time: 3.25s
# Round 341 | Acc: 72.10% | Sim Time: 3.26s
# Round 342 | Acc: 72.05% | Sim Time: 3.27s
# Round 343 | Acc: 72.10% | Sim Time: 3.28s
# Round 344 | Acc: 72.15% | Sim Time: 3.29s
# Round 345 | Acc: 72.10% | Sim Time: 3.31s
# Round 346 | Acc: 72.10% | Sim Time: 3.31s
# Round 347 | Acc: 72.15% | Sim Time: 3.32s
# Round 348 | Acc: 72.10% | Sim Time: 3.33s
# Round 349 | Acc: 72.15% | Sim Time: 3.34s
# Round 350 | Acc: 72.15% | Sim Time: 3.35s
# Round 351 | Acc: 72.15% | Sim Time: 3.36s
# Round 352 | Acc: 72.15% | Sim Time: 3.37s
# Round 353 | Acc: 72.10% | Sim Time: 3.38s
# Round 354 | Acc: 72.15% | Sim Time: 3.39s
# Round 355 | Acc: 72.15% | Sim Time: 3.40s
# Round 356 | Acc: 72.15% | Sim Time: 3.41s
# Round 357 | Acc: 72.10% | Sim Time: 3.42s
# Round 358 | Acc: 72.15% | Sim Time: 3.43s
# Round 359 | Acc: 72.10% | Sim Time: 3.44s
# Round 360 | Acc: 72.20% | Sim Time: 3.45s
# Round 361 | Acc: 72.30% | Sim Time: 3.46s
# Round 362 | Acc: 72.30% | Sim Time: 3.47s
# Round 363 | Acc: 72.40% | Sim Time: 3.48s
# Round 364 | Acc: 72.35% | Sim Time: 3.49s
# Round 365 | Acc: 72.55% | Sim Time: 3.50s
# Round 366 | Acc: 72.40% | Sim Time: 3.51s
# Round 367 | Acc: 72.60% | Sim Time: 3.52s
# Round 368 | Acc: 72.50% | Sim Time: 3.53s
# Round 369 | Acc: 72.55% | Sim Time: 3.54s
# Round 370 | Acc: 72.30% | Sim Time: 3.55s
# Round 371 | Acc: 72.40% | Sim Time: 3.56s
# Round 372 | Acc: 72.45% | Sim Time: 3.57s
# Round 373 | Acc: 72.35% | Sim Time: 3.58s
# Round 374 | Acc: 72.35% | Sim Time: 3.59s
# Round 375 | Acc: 72.35% | Sim Time: 3.60s
# Round 376 | Acc: 72.40% | Sim Time: 3.61s
# Round 377 | Acc: 72.35% | Sim Time: 3.62s
# Round 378 | Acc: 72.35% | Sim Time: 3.63s
# Round 379 | Acc: 72.50% | Sim Time: 3.64s
# Round 380 | Acc: 72.40% | Sim Time: 3.65s
# Round 381 | Acc: 72.65% | Sim Time: 3.66s
# Round 382 | Acc: 72.85% | Sim Time: 3.67s
# Round 383 | Acc: 72.75% | Sim Time: 3.68s
# Round 384 | Acc: 72.75% | Sim Time: 3.69s
# Round 385 | Acc: 72.95% | Sim Time: 3.70s
# Round 386 | Acc: 72.80% | Sim Time: 3.71s
# Round 387 | Acc: 72.95% | Sim Time: 3.72s
# Round 388 | Acc: 72.95% | Sim Time: 3.73s
# Round 389 | Acc: 72.95% | Sim Time: 3.74s
# Round 390 | Acc: 73.00% | Sim Time: 3.75s
# Round 391 | Acc: 72.95% | Sim Time: 3.76s
# Round 392 | Acc: 72.90% | Sim Time: 3.77s
# Round 393 | Acc: 72.85% | Sim Time: 3.78s
# Round 394 | Acc: 72.95% | Sim Time: 3.79s
# Round 395 | Acc: 72.90% | Sim Time: 3.80s
# Round 396 | Acc: 73.05% | Sim Time: 3.81s
# Round 397 | Acc: 73.00% | Sim Time: 3.82s
# Round 398 | Acc: 73.10% | Sim Time: 3.83s
# Round 399 | Acc: 73.00% | Sim Time: 3.84s
# Round 400 | Acc: 73.10% | Sim Time: 3.85s
# Round 401 | Acc: 73.05% | Sim Time: 3.86s
# Round 402 | Acc: 73.20% | Sim Time: 3.87s
# Round 403 | Acc: 73.25% | Sim Time: 3.88s
# Round 404 | Acc: 73.25% | Sim Time: 3.89s
# Round 405 | Acc: 73.30% | Sim Time: 3.90s
# Round 406 | Acc: 73.30% | Sim Time: 3.91s
# Round 407 | Acc: 73.30% | Sim Time: 3.92s
# Round 408 | Acc: 73.35% | Sim Time: 3.93s
# Round 409 | Acc: 73.30% | Sim Time: 3.94s
# Round 410 | Acc: 73.45% | Sim Time: 3.95s
# Round 411 | Acc: 73.30% | Sim Time: 3.96s
# Round 412 | Acc: 73.30% | Sim Time: 3.97s
# Round 413 | Acc: 73.40% | Sim Time: 3.98s
# Round 414 | Acc: 73.35% | Sim Time: 3.99s
# Round 415 | Acc: 73.40% | Sim Time: 4.00s
# Round 416 | Acc: 73.40% | Sim Time: 4.01s
# Round 417 | Acc: 73.40% | Sim Time: 4.02s
# Round 418 | Acc: 73.45% | Sim Time: 4.03s
# Round 419 | Acc: 73.40% | Sim Time: 4.04s
# Round 420 | Acc: 73.40% | Sim Time: 4.04s
# Round 421 | Acc: 73.35% | Sim Time: 4.05s
# Round 422 | Acc: 73.40% | Sim Time: 4.06s
# Round 423 | Acc: 73.40% | Sim Time: 4.07s
# Round 424 | Acc: 73.45% | Sim Time: 4.08s
# Round 425 | Acc: 73.40% | Sim Time: 4.09s
# Round 426 | Acc: 73.40% | Sim Time: 4.10s
# Round 427 | Acc: 73.40% | Sim Time: 4.11s
# Round 428 | Acc: 73.45% | Sim Time: 4.12s
# Round 429 | Acc: 73.45% | Sim Time: 4.13s
# Round 430 | Acc: 73.45% | Sim Time: 4.14s
# Round 431 | Acc: 73.60% | Sim Time: 4.15s
# Round 432 | Acc: 73.60% | Sim Time: 4.16s
# Round 433 | Acc: 73.45% | Sim Time: 4.17s
# Round 434 | Acc: 73.40% | Sim Time: 4.18s
# Round 435 | Acc: 73.45% | Sim Time: 4.19s
# Round 436 | Acc: 73.45% | Sim Time: 4.20s
# Round 437 | Acc: 73.40% | Sim Time: 4.21s
# Round 438 | Acc: 73.50% | Sim Time: 4.22s
# Round 439 | Acc: 73.55% | Sim Time: 4.23s
# Round 440 | Acc: 73.50% | Sim Time: 4.24s
# Round 441 | Acc: 73.45% | Sim Time: 4.24s
# Round 442 | Acc: 73.45% | Sim Time: 4.25s
# Round 443 | Acc: 73.55% | Sim Time: 4.26s
# Round 444 | Acc: 73.50% | Sim Time: 4.27s
# Round 445 | Acc: 73.45% | Sim Time: 4.28s
# Round 446 | Acc: 73.50% | Sim Time: 4.29s
# Round 447 | Acc: 73.45% | Sim Time: 4.30s
# Round 448 | Acc: 73.50% | Sim Time: 4.31s
# Round 449 | Acc: 73.45% | Sim Time: 4.32s
# Round 450 | Acc: 73.45% | Sim Time: 4.33s
# Round 451 | Acc: 73.45% | Sim Time: 4.34s
# Round 452 | Acc: 73.50% | Sim Time: 4.35s
# Round 453 | Acc: 73.45% | Sim Time: 4.36s
# Round 454 | Acc: 73.55% | Sim Time: 4.37s
# Round 455 | Acc: 73.50% | Sim Time: 4.38s
# Round 456 | Acc: 73.50% | Sim Time: 4.39s
# Round 457 | Acc: 73.45% | Sim Time: 4.40s
# Round 458 | Acc: 73.45% | Sim Time: 4.41s
# Round 459 | Acc: 73.40% | Sim Time: 4.42s
# Round 460 | Acc: 73.40% | Sim Time: 4.42s
# Round 461 | Acc: 73.55% | Sim Time: 4.44s
# Round 462 | Acc: 73.45% | Sim Time: 4.44s
# Round 463 | Acc: 73.55% | Sim Time: 4.45s
# Round 464 | Acc: 73.45% | Sim Time: 4.46s
# Round 465 | Acc: 73.40% | Sim Time: 4.47s
# Round 466 | Acc: 73.40% | Sim Time: 4.48s
# Round 467 | Acc: 73.40% | Sim Time: 4.49s
# Round 468 | Acc: 73.55% | Sim Time: 4.50s
# Round 469 | Acc: 73.50% | Sim Time: 4.51s
# Round 470 | Acc: 73.40% | Sim Time: 4.52s
# Round 471 | Acc: 73.40% | Sim Time: 4.53s
# Round 472 | Acc: 73.40% | Sim Time: 4.54s
# Round 473 | Acc: 73.60% | Sim Time: 4.55s
# Round 474 | Acc: 73.50% | Sim Time: 4.56s
# Round 475 | Acc: 73.55% | Sim Time: 4.57s
# Round 476 | Acc: 73.65% | Sim Time: 4.58s
# Round 477 | Acc: 73.75% | Sim Time: 4.59s
# Round 478 | Acc: 73.65% | Sim Time: 4.60s
# Round 479 | Acc: 73.65% | Sim Time: 4.61s
# Round 480 | Acc: 73.55% | Sim Time: 4.62s
# Round 481 | Acc: 73.70% | Sim Time: 4.62s
# Round 482 | Acc: 73.55% | Sim Time: 4.63s
# Round 483 | Acc: 73.75% | Sim Time: 4.64s
# Round 484 | Acc: 73.75% | Sim Time: 4.65s
# Round 485 | Acc: 73.65% | Sim Time: 4.67s
# Round 486 | Acc: 73.70% | Sim Time: 4.68s
# Round 487 | Acc: 73.75% | Sim Time: 4.68s
# Round 488 | Acc: 73.80% | Sim Time: 4.70s
# Round 489 | Acc: 73.75% | Sim Time: 4.71s
# Round 490 | Acc: 73.80% | Sim Time: 4.72s
# Round 491 | Acc: 73.90% | Sim Time: 4.73s
# Round 492 | Acc: 74.00% | Sim Time: 4.74s
# Round 493 | Acc: 74.10% | Sim Time: 4.75s
# Round 494 | Acc: 74.05% | Sim Time: 4.76s
# Round 495 | Acc: 74.05% | Sim Time: 4.77s
# Round 496 | Acc: 74.05% | Sim Time: 4.78s
# Round 497 | Acc: 74.20% | Sim Time: 4.79s
# Round 498 | Acc: 74.35% | Sim Time: 4.80s
# Round 499 | Acc: 74.45% | Sim Time: 4.81s
# Round 500 | Acc: 74.35% | Sim Time: 4.82s
# Round 501 | Acc: 74.30% | Sim Time: 4.83s
# Round 502 | Acc: 74.10% | Sim Time: 4.84s
# Round 503 | Acc: 74.05% | Sim Time: 4.85s
# Round 504 | Acc: 74.10% | Sim Time: 4.86s
# Round 505 | Acc: 74.15% | Sim Time: 4.87s
# Round 506 | Acc: 74.20% | Sim Time: 4.88s
# Round 507 | Acc: 74.40% | Sim Time: 4.89s
# Round 508 | Acc: 74.45% | Sim Time: 4.90s
# Round 509 | Acc: 74.60% | Sim Time: 4.91s
# Round 510 | Acc: 74.60% | Sim Time: 4.92s
# Round 511 | Acc: 74.65% | Sim Time: 4.93s
# Round 512 | Acc: 74.65% | Sim Time: 4.94s
# Round 513 | Acc: 74.70% | Sim Time: 4.95s
# Round 514 | Acc: 74.70% | Sim Time: 4.96s
# Round 515 | Acc: 74.75% | Sim Time: 4.97s
# Round 516 | Acc: 74.70% | Sim Time: 4.98s
# Round 517 | Acc: 74.75% | Sim Time: 4.99s
# Round 518 | Acc: 74.75% | Sim Time: 5.00s
# Round 519 | Acc: 74.75% | Sim Time: 5.01s
# Round 520 | Acc: 74.75% | Sim Time: 5.02s
# Round 521 | Acc: 74.75% | Sim Time: 5.03s
# Round 522 | Acc: 74.75% | Sim Time: 5.04s
# Round 523 | Acc: 74.80% | Sim Time: 5.05s
# Round 524 | Acc: 74.75% | Sim Time: 5.06s
# Round 525 | Acc: 74.80% | Sim Time: 5.07s
# Round 526 | Acc: 74.90% | Sim Time: 5.08s
# Round 527 | Acc: 74.95% | Sim Time: 5.09s
# Round 528 | Acc: 74.95% | Sim Time: 5.10s
# Round 529 | Acc: 74.90% | Sim Time: 5.11s
# Round 530 | Acc: 74.95% | Sim Time: 5.12s
# Round 531 | Acc: 74.90% | Sim Time: 5.13s
# Round 532 | Acc: 74.95% | Sim Time: 5.13s
# Round 533 | Acc: 74.90% | Sim Time: 5.15s
# Round 534 | Acc: 74.95% | Sim Time: 5.15s
# Round 535 | Acc: 74.95% | Sim Time: 5.16s
# Round 536 | Acc: 74.85% | Sim Time: 5.17s
# Round 537 | Acc: 74.85% | Sim Time: 5.19s
# Round 538 | Acc: 74.85% | Sim Time: 5.20s
# Round 539 | Acc: 74.90% | Sim Time: 5.20s
# Round 540 | Acc: 74.95% | Sim Time: 5.21s
# Round 541 | Acc: 74.95% | Sim Time: 5.23s
# Round 542 | Acc: 74.95% | Sim Time: 5.24s
# Round 543 | Acc: 74.90% | Sim Time: 5.25s
# Round 544 | Acc: 74.95% | Sim Time: 5.26s
# Round 545 | Acc: 74.95% | Sim Time: 5.27s
# Round 546 | Acc: 74.90% | Sim Time: 5.28s
# Round 547 | Acc: 74.95% | Sim Time: 5.29s
# Round 548 | Acc: 74.90% | Sim Time: 5.30s
# Round 549 | Acc: 74.85% | Sim Time: 5.30s
# Round 550 | Acc: 74.90% | Sim Time: 5.32s
# Round 551 | Acc: 74.90% | Sim Time: 5.33s
# Round 552 | Acc: 74.95% | Sim Time: 5.34s
# Round 553 | Acc: 74.90% | Sim Time: 5.35s
# Round 554 | Acc: 74.95% | Sim Time: 5.36s
# Round 555 | Acc: 74.90% | Sim Time: 5.37s
# Round 556 | Acc: 74.95% | Sim Time: 5.38s
# Round 557 | Acc: 74.90% | Sim Time: 5.39s
# Round 558 | Acc: 75.00% | Sim Time: 5.40s
# Round 559 | Acc: 74.90% | Sim Time: 5.41s
# Round 560 | Acc: 75.00% | Sim Time: 5.42s
# Round 561 | Acc: 74.95% | Sim Time: 5.43s
# Round 562 | Acc: 75.00% | Sim Time: 5.44s
# Round 563 | Acc: 74.95% | Sim Time: 5.44s
# Round 564 | Acc: 74.95% | Sim Time: 5.45s
# Round 565 | Acc: 74.90% | Sim Time: 5.46s
# Round 566 | Acc: 74.90% | Sim Time: 5.47s
# Round 567 | Acc: 74.95% | Sim Time: 5.48s
# Round 568 | Acc: 75.00% | Sim Time: 5.49s
# Round 569 | Acc: 74.95% | Sim Time: 5.50s
# Round 570 | Acc: 74.90% | Sim Time: 5.51s
# Round 571 | Acc: 74.90% | Sim Time: 5.52s
# Round 572 | Acc: 74.95% | Sim Time: 5.53s
# Round 573 | Acc: 75.00% | Sim Time: 5.54s
# Round 574 | Acc: 74.90% | Sim Time: 5.55s
# Round 575 | Acc: 75.00% | Sim Time: 5.56s
# Round 576 | Acc: 75.15% | Sim Time: 5.57s
# Round 577 | Acc: 75.25% | Sim Time: 5.59s
# Round 578 | Acc: 75.15% | Sim Time: 5.60s
# Round 579 | Acc: 75.10% | Sim Time: 5.61s
# Round 580 | Acc: 75.00% | Sim Time: 5.62s
# Round 581 | Acc: 75.05% | Sim Time: 5.63s
# Round 582 | Acc: 75.05% | Sim Time: 5.63s
# Round 583 | Acc: 75.10% | Sim Time: 5.64s
# Round 584 | Acc: 75.25% | Sim Time: 5.65s
# Round 585 | Acc: 75.15% | Sim Time: 5.66s
# Round 586 | Acc: 75.05% | Sim Time: 5.67s
# Round 587 | Acc: 75.15% | Sim Time: 5.68s
# Round 588 | Acc: 75.25% | Sim Time: 5.69s
# Round 589 | Acc: 75.25% | Sim Time: 5.70s
# Round 590 | Acc: 75.20% | Sim Time: 5.71s
# Round 591 | Acc: 75.25% | Sim Time: 5.72s
# Round 592 | Acc: 75.50% | Sim Time: 5.73s
# Round 593 | Acc: 75.25% | Sim Time: 5.74s
# Round 594 | Acc: 75.55% | Sim Time: 5.75s
# Round 595 | Acc: 75.30% | Sim Time: 5.76s
# Round 596 | Acc: 75.20% | Sim Time: 5.77s
# Round 597 | Acc: 75.15% | Sim Time: 5.78s
# Round 598 | Acc: 75.30% | Sim Time: 5.79s
# Round 599 | Acc: 75.20% | Sim Time: 5.80s
# Round 600 | Acc: 75.10% | Sim Time: 5.80s
# Round 601 | Acc: 75.20% | Sim Time: 5.81s
# Round 602 | Acc: 75.10% | Sim Time: 5.82s
# Round 603 | Acc: 75.20% | Sim Time: 5.83s
# Round 604 | Acc: 75.20% | Sim Time: 5.84s
# Round 605 | Acc: 75.10% | Sim Time: 5.85s
# Round 606 | Acc: 75.20% | Sim Time: 5.86s
# Round 607 | Acc: 75.20% | Sim Time: 5.87s
# Round 608 | Acc: 75.20% | Sim Time: 5.87s
# Round 609 | Acc: 75.20% | Sim Time: 5.88s
# Round 610 | Acc: 75.20% | Sim Time: 5.89s
# Round 611 | Acc: 75.20% | Sim Time: 5.90s
# Round 612 | Acc: 75.20% | Sim Time: 5.91s
# Round 613 | Acc: 75.20% | Sim Time: 5.92s
# Round 614 | Acc: 75.20% | Sim Time: 5.94s
# Round 615 | Acc: 75.25% | Sim Time: 5.95s
# Round 616 | Acc: 75.15% | Sim Time: 5.95s
# Round 617 | Acc: 75.20% | Sim Time: 5.96s
# Round 618 | Acc: 75.15% | Sim Time: 5.97s
# Round 619 | Acc: 75.20% | Sim Time: 5.98s
# Round 620 | Acc: 75.20% | Sim Time: 5.99s
# Round 621 | Acc: 75.40% | Sim Time: 6.00s
# Round 622 | Acc: 75.20% | Sim Time: 6.01s
# Round 623 | Acc: 75.20% | Sim Time: 6.02s
# Round 624 | Acc: 75.35% | Sim Time: 6.03s
# Round 625 | Acc: 75.60% | Sim Time: 6.04s
# Round 626 | Acc: 75.75% | Sim Time: 6.06s
# Round 627 | Acc: 75.70% | Sim Time: 6.07s
# Round 628 | Acc: 75.80% | Sim Time: 6.07s
# Round 629 | Acc: 75.70% | Sim Time: 6.08s
# Round 630 | Acc: 75.75% | Sim Time: 6.09s
# Round 631 | Acc: 75.70% | Sim Time: 6.10s
# Round 632 | Acc: 75.70% | Sim Time: 6.11s
# Round 633 | Acc: 75.65% | Sim Time: 6.12s
# Round 634 | Acc: 75.70% | Sim Time: 6.13s
# Round 635 | Acc: 75.60% | Sim Time: 6.14s
# Round 636 | Acc: 75.60% | Sim Time: 6.15s
# Round 637 | Acc: 75.50% | Sim Time: 6.16s
# Round 638 | Acc: 75.45% | Sim Time: 6.17s
# Round 639 | Acc: 75.50% | Sim Time: 6.18s
# Round 640 | Acc: 75.55% | Sim Time: 6.18s
# Round 641 | Acc: 75.45% | Sim Time: 6.19s
# Round 642 | Acc: 75.45% | Sim Time: 6.20s
# Round 643 | Acc: 75.50% | Sim Time: 6.21s
# Round 644 | Acc: 75.45% | Sim Time: 6.22s
# Round 645 | Acc: 75.45% | Sim Time: 6.23s
# Round 646 | Acc: 75.45% | Sim Time: 6.24s
# Round 647 | Acc: 75.35% | Sim Time: 6.25s
# Round 648 | Acc: 75.30% | Sim Time: 6.26s
# Round 649 | Acc: 75.45% | Sim Time: 6.27s
# Round 650 | Acc: 75.50% | Sim Time: 6.28s
# Round 651 | Acc: 75.50% | Sim Time: 6.29s
# Round 652 | Acc: 75.55% | Sim Time: 6.30s
# Round 653 | Acc: 75.60% | Sim Time: 6.31s
# Round 654 | Acc: 75.80% | Sim Time: 6.32s
# Round 655 | Acc: 75.70% | Sim Time: 6.33s
# Round 656 | Acc: 75.65% | Sim Time: 6.34s
# Round 657 | Acc: 75.75% | Sim Time: 6.35s
# Round 658 | Acc: 75.85% | Sim Time: 6.36s
# Round 659 | Acc: 75.85% | Sim Time: 6.37s
# Round 660 | Acc: 75.90% | Sim Time: 6.38s
# Round 661 | Acc: 75.85% | Sim Time: 6.39s
# Round 662 | Acc: 75.85% | Sim Time: 6.40s
# Round 663 | Acc: 75.85% | Sim Time: 6.41s
# Round 664 | Acc: 75.85% | Sim Time: 6.42s
# Round 665 | Acc: 75.75% | Sim Time: 6.43s
# Round 666 | Acc: 75.70% | Sim Time: 6.44s
# Round 667 | Acc: 75.80% | Sim Time: 6.45s
# Round 668 | Acc: 75.70% | Sim Time: 6.46s
# Round 669 | Acc: 75.75% | Sim Time: 6.47s
# Round 670 | Acc: 75.70% | Sim Time: 6.48s
# Round 671 | Acc: 75.70% | Sim Time: 6.49s
# Round 672 | Acc: 75.70% | Sim Time: 6.50s
# Round 673 | Acc: 75.75% | Sim Time: 6.51s
# Round 674 | Acc: 75.75% | Sim Time: 6.52s
# Round 675 | Acc: 75.70% | Sim Time: 6.53s
# Round 676 | Acc: 75.70% | Sim Time: 6.54s
# Round 677 | Acc: 75.65% | Sim Time: 6.54s
# Round 678 | Acc: 75.75% | Sim Time: 6.55s
# Round 679 | Acc: 75.80% | Sim Time: 6.56s
# Round 680 | Acc: 75.75% | Sim Time: 6.57s
# Round 681 | Acc: 75.75% | Sim Time: 6.58s
# Round 682 | Acc: 75.70% | Sim Time: 6.59s
# Round 683 | Acc: 75.75% | Sim Time: 6.60s
# Round 684 | Acc: 75.80% | Sim Time: 6.61s
# Round 685 | Acc: 75.85% | Sim Time: 6.62s
# Round 686 | Acc: 75.95% | Sim Time: 6.63s
# Round 687 | Acc: 75.90% | Sim Time: 6.64s
# Round 688 | Acc: 75.95% | Sim Time: 6.65s
# Round 689 | Acc: 75.90% | Sim Time: 6.66s
# Round 690 | Acc: 75.95% | Sim Time: 6.68s
# Round 691 | Acc: 75.95% | Sim Time: 6.68s
# Round 692 | Acc: 75.80% | Sim Time: 6.69s
# Round 693 | Acc: 75.75% | Sim Time: 6.70s
# Round 694 | Acc: 75.80% | Sim Time: 6.71s
# Round 695 | Acc: 75.80% | Sim Time: 6.72s
# Round 696 | Acc: 75.75% | Sim Time: 6.73s
# Round 697 | Acc: 75.80% | Sim Time: 6.74s
# Round 698 | Acc: 75.80% | Sim Time: 6.74s
# Round 699 | Acc: 75.75% | Sim Time: 6.75s
# Round 700 | Acc: 75.80% | Sim Time: 6.76s
# Round 701 | Acc: 75.80% | Sim Time: 6.77s
# Round 702 | Acc: 75.85% | Sim Time: 6.78s
# Round 703 | Acc: 75.90% | Sim Time: 6.79s
# Round 704 | Acc: 75.95% | Sim Time: 6.80s
# Round 705 | Acc: 75.95% | Sim Time: 6.81s
# Round 706 | Acc: 76.00% | Sim Time: 6.82s
# Round 707 | Acc: 76.00% | Sim Time: 6.83s
# Round 708 | Acc: 76.00% | Sim Time: 6.84s
# Round 709 | Acc: 76.05% | Sim Time: 6.85s
# Round 710 | Acc: 76.05% | Sim Time: 6.86s
# Round 711 | Acc: 76.05% | Sim Time: 6.86s
# Round 712 | Acc: 76.00% | Sim Time: 6.87s
# Round 713 | Acc: 76.05% | Sim Time: 6.88s
# Round 714 | Acc: 76.05% | Sim Time: 6.90s
# Round 715 | Acc: 76.00% | Sim Time: 6.90s
# Round 716 | Acc: 76.05% | Sim Time: 6.91s
# Round 717 | Acc: 76.05% | Sim Time: 6.92s
# Round 718 | Acc: 76.05% | Sim Time: 6.93s
# Round 719 | Acc: 76.20% | Sim Time: 6.94s
# Round 720 | Acc: 76.20% | Sim Time: 6.95s
# Round 721 | Acc: 76.25% | Sim Time: 6.96s
# Round 722 | Acc: 76.30% | Sim Time: 6.97s
# Round 723 | Acc: 76.30% | Sim Time: 6.98s
# Round 724 | Acc: 76.30% | Sim Time: 7.00s
# Round 725 | Acc: 76.40% | Sim Time: 7.01s
# Round 726 | Acc: 76.40% | Sim Time: 7.02s
# Round 727 | Acc: 76.25% | Sim Time: 7.03s
# Round 728 | Acc: 76.40% | Sim Time: 7.04s
# Round 729 | Acc: 76.30% | Sim Time: 7.05s
# Round 730 | Acc: 76.40% | Sim Time: 7.06s
# Round 731 | Acc: 76.40% | Sim Time: 7.07s
# Round 732 | Acc: 76.45% | Sim Time: 7.08s
# Round 733 | Acc: 76.45% | Sim Time: 7.09s
# Round 734 | Acc: 76.40% | Sim Time: 7.10s
# Round 735 | Acc: 76.25% | Sim Time: 7.10s
# Round 736 | Acc: 76.40% | Sim Time: 7.11s
# Round 737 | Acc: 76.45% | Sim Time: 7.12s
# Round 738 | Acc: 76.35% | Sim Time: 7.13s
# Round 739 | Acc: 76.25% | Sim Time: 7.14s
# Round 740 | Acc: 76.35% | Sim Time: 7.15s
# Round 741 | Acc: 76.25% | Sim Time: 7.16s
# Round 742 | Acc: 76.25% | Sim Time: 7.17s
# Round 743 | Acc: 76.25% | Sim Time: 7.18s
# Round 744 | Acc: 76.15% | Sim Time: 7.19s
# Round 745 | Acc: 76.25% | Sim Time: 7.20s
# Round 746 | Acc: 76.20% | Sim Time: 7.21s
# Round 747 | Acc: 76.20% | Sim Time: 7.22s
# Round 748 | Acc: 76.20% | Sim Time: 7.23s
# Round 749 | Acc: 76.20% | Sim Time: 7.24s
# Round 750 | Acc: 76.25% | Sim Time: 7.25s
# Round 751 | Acc: 76.20% | Sim Time: 7.25s
# Round 752 | Acc: 76.20% | Sim Time: 7.26s
# Round 753 | Acc: 76.20% | Sim Time: 7.28s
# Round 754 | Acc: 76.20% | Sim Time: 7.29s
# Round 755 | Acc: 76.10% | Sim Time: 7.30s
# Round 756 | Acc: 76.15% | Sim Time: 7.31s
# Round 757 | Acc: 76.15% | Sim Time: 7.32s
# Round 758 | Acc: 76.10% | Sim Time: 7.33s
# Round 759 | Acc: 76.20% | Sim Time: 7.33s
# Round 760 | Acc: 76.15% | Sim Time: 7.34s
# Round 761 | Acc: 76.15% | Sim Time: 7.36s
# Round 762 | Acc: 76.25% | Sim Time: 7.37s
# Round 763 | Acc: 76.15% | Sim Time: 7.38s
# Round 764 | Acc: 76.15% | Sim Time: 7.39s
# Round 765 | Acc: 76.15% | Sim Time: 7.40s
# Round 766 | Acc: 76.10% | Sim Time: 7.40s
# Round 767 | Acc: 76.15% | Sim Time: 7.41s
# Round 768 | Acc: 76.25% | Sim Time: 7.43s
# Round 769 | Acc: 76.30% | Sim Time: 7.44s
# Round 770 | Acc: 76.35% | Sim Time: 7.44s
# Round 771 | Acc: 76.30% | Sim Time: 7.45s
# Round 772 | Acc: 76.30% | Sim Time: 7.46s
# Round 773 | Acc: 76.25% | Sim Time: 7.47s
# Round 774 | Acc: 76.30% | Sim Time: 7.48s
# Round 775 | Acc: 76.35% | Sim Time: 7.49s
# Round 776 | Acc: 76.30% | Sim Time: 7.50s
# Round 777 | Acc: 76.30% | Sim Time: 7.51s
# Round 778 | Acc: 76.25% | Sim Time: 7.52s
# Round 779 | Acc: 76.20% | Sim Time: 7.52s
# Round 780 | Acc: 76.30% | Sim Time: 7.53s
# Round 781 | Acc: 76.25% | Sim Time: 7.54s
# Round 782 | Acc: 76.30% | Sim Time: 7.55s
# Round 783 | Acc: 76.25% | Sim Time: 7.56s
# Round 784 | Acc: 76.20% | Sim Time: 7.57s
# Round 785 | Acc: 76.25% | Sim Time: 7.57s
# Round 786 | Acc: 76.35% | Sim Time: 7.58s
# Round 787 | Acc: 76.30% | Sim Time: 7.59s
# Round 788 | Acc: 76.35% | Sim Time: 7.60s
# Round 789 | Acc: 76.20% | Sim Time: 7.61s
# Round 790 | Acc: 76.30% | Sim Time: 7.62s
# Round 791 | Acc: 76.20% | Sim Time: 7.63s
# Round 792 | Acc: 76.25% | Sim Time: 7.64s
# Round 793 | Acc: 76.35% | Sim Time: 7.65s
# Round 794 | Acc: 76.25% | Sim Time: 7.66s
# Round 795 | Acc: 76.30% | Sim Time: 7.66s
# Round 796 | Acc: 76.25% | Sim Time: 7.67s
# Round 797 | Acc: 76.25% | Sim Time: 7.68s
# Round 798 | Acc: 76.30% | Sim Time: 7.69s
# Round 799 | Acc: 76.30% | Sim Time: 7.70s
# Round 800 | Acc: 76.30% | Sim Time: 7.71s
# Round 801 | Acc: 76.35% | Sim Time: 7.72s
# Round 802 | Acc: 76.30% | Sim Time: 7.73s
# Round 803 | Acc: 76.35% | Sim Time: 7.74s
# Round 804 | Acc: 76.35% | Sim Time: 7.75s
# Round 805 | Acc: 76.30% | Sim Time: 7.76s
# Round 806 | Acc: 76.35% | Sim Time: 7.77s
# Round 807 | Acc: 76.30% | Sim Time: 7.78s
# Round 808 | Acc: 76.35% | Sim Time: 7.79s
# Round 809 | Acc: 76.35% | Sim Time: 7.80s
# Round 810 | Acc: 76.35% | Sim Time: 7.81s
# Round 811 | Acc: 76.25% | Sim Time: 7.82s
# Round 812 | Acc: 76.30% | Sim Time: 7.83s
# Round 813 | Acc: 76.35% | Sim Time: 7.84s
# Round 814 | Acc: 76.30% | Sim Time: 7.85s
# Round 815 | Acc: 76.35% | Sim Time: 7.86s
# Round 816 | Acc: 76.40% | Sim Time: 7.87s
# Round 817 | Acc: 76.40% | Sim Time: 7.88s
# Round 818 | Acc: 76.40% | Sim Time: 7.89s
# Round 819 | Acc: 76.45% | Sim Time: 7.90s
# Round 820 | Acc: 76.35% | Sim Time: 7.91s
# Round 821 | Acc: 76.30% | Sim Time: 7.92s
# Round 822 | Acc: 76.35% | Sim Time: 7.93s
# Round 823 | Acc: 76.35% | Sim Time: 7.94s
# Round 824 | Acc: 76.35% | Sim Time: 7.95s
# Round 825 | Acc: 76.30% | Sim Time: 7.96s
# Round 826 | Acc: 76.40% | Sim Time: 7.97s
# Round 827 | Acc: 76.45% | Sim Time: 7.98s
# Round 828 | Acc: 76.45% | Sim Time: 7.98s
# Round 829 | Acc: 76.40% | Sim Time: 7.99s
# Round 830 | Acc: 76.45% | Sim Time: 8.00s
# Round 831 | Acc: 76.40% | Sim Time: 8.01s
# Round 832 | Acc: 76.50% | Sim Time: 8.02s
# Round 833 | Acc: 76.40% | Sim Time: 8.03s
# Round 834 | Acc: 76.45% | Sim Time: 8.04s
# Round 835 | Acc: 76.35% | Sim Time: 8.05s
# Round 836 | Acc: 76.45% | Sim Time: 8.06s
# Round 837 | Acc: 76.35% | Sim Time: 8.07s
# Round 838 | Acc: 76.40% | Sim Time: 8.08s
# Round 839 | Acc: 76.30% | Sim Time: 8.09s
# Round 840 | Acc: 76.35% | Sim Time: 8.10s
# Round 841 | Acc: 76.50% | Sim Time: 8.11s
# Round 842 | Acc: 76.35% | Sim Time: 8.12s
# Round 843 | Acc: 76.45% | Sim Time: 8.13s
# Round 844 | Acc: 76.50% | Sim Time: 8.14s
# Round 845 | Acc: 76.45% | Sim Time: 8.15s
# Round 846 | Acc: 76.45% | Sim Time: 8.16s
# Round 847 | Acc: 76.35% | Sim Time: 8.17s
# Round 848 | Acc: 76.35% | Sim Time: 8.18s
# Round 849 | Acc: 76.40% | Sim Time: 8.19s
# Round 850 | Acc: 76.45% | Sim Time: 8.20s
# Round 851 | Acc: 76.45% | Sim Time: 8.21s
# Round 852 | Acc: 76.40% | Sim Time: 8.22s
# Round 853 | Acc: 76.45% | Sim Time: 8.23s
# Round 854 | Acc: 76.40% | Sim Time: 8.24s
# Round 855 | Acc: 76.45% | Sim Time: 8.25s
# Round 856 | Acc: 76.40% | Sim Time: 8.26s
# Round 857 | Acc: 76.45% | Sim Time: 8.27s
# Round 858 | Acc: 76.45% | Sim Time: 8.28s
# Round 859 | Acc: 76.50% | Sim Time: 8.29s
# Round 860 | Acc: 76.50% | Sim Time: 8.30s
# Round 861 | Acc: 76.40% | Sim Time: 8.31s
# Round 862 | Acc: 76.50% | Sim Time: 8.32s
# Round 863 | Acc: 76.40% | Sim Time: 8.33s
# Round 864 | Acc: 76.45% | Sim Time: 8.33s
# Round 865 | Acc: 76.50% | Sim Time: 8.34s
# Round 866 | Acc: 76.45% | Sim Time: 8.35s
# Round 867 | Acc: 76.55% | Sim Time: 8.37s
# Round 868 | Acc: 76.45% | Sim Time: 8.37s
# Round 869 | Acc: 76.55% | Sim Time: 8.38s
# Round 870 | Acc: 76.45% | Sim Time: 8.39s
# Round 871 | Acc: 76.60% | Sim Time: 8.40s
# Round 872 | Acc: 76.60% | Sim Time: 8.41s
# Round 873 | Acc: 76.50% | Sim Time: 8.42s
# Round 874 | Acc: 76.55% | Sim Time: 8.43s
# Round 875 | Acc: 76.55% | Sim Time: 8.44s
# Round 876 | Acc: 76.50% | Sim Time: 8.45s
# Round 877 | Acc: 76.60% | Sim Time: 8.45s
# Round 878 | Acc: 76.50% | Sim Time: 8.46s
# Round 879 | Acc: 76.50% | Sim Time: 8.47s
# Round 880 | Acc: 76.55% | Sim Time: 8.48s
# Round 881 | Acc: 76.55% | Sim Time: 8.49s
# Round 882 | Acc: 76.55% | Sim Time: 8.50s
# Round 883 | Acc: 76.55% | Sim Time: 8.51s
# Round 884 | Acc: 76.55% | Sim Time: 8.51s
# Round 885 | Acc: 76.60% | Sim Time: 8.52s
# Round 886 | Acc: 76.65% | Sim Time: 8.53s
# Round 887 | Acc: 76.60% | Sim Time: 8.54s
# Round 888 | Acc: 76.60% | Sim Time: 8.55s
# Round 889 | Acc: 76.65% | Sim Time: 8.56s
# Round 890 | Acc: 76.65% | Sim Time: 8.57s
# Round 891 | Acc: 76.65% | Sim Time: 8.58s
# Round 892 | Acc: 76.80% | Sim Time: 8.60s
# Round 893 | Acc: 76.70% | Sim Time: 8.60s
# Round 894 | Acc: 76.80% | Sim Time: 8.61s
# Round 895 | Acc: 76.75% | Sim Time: 8.62s
# Round 896 | Acc: 76.80% | Sim Time: 8.63s
# Round 897 | Acc: 76.80% | Sim Time: 8.64s
# Round 898 | Acc: 76.85% | Sim Time: 8.65s
# Round 899 | Acc: 76.80% | Sim Time: 8.66s
# Round 900 | Acc: 76.80% | Sim Time: 8.67s
# Round 901 | Acc: 76.90% | Sim Time: 8.68s
# Round 902 | Acc: 76.80% | Sim Time: 8.69s
# Round 903 | Acc: 76.90% | Sim Time: 8.70s
# Round 904 | Acc: 76.90% | Sim Time: 8.71s
# Round 905 | Acc: 76.85% | Sim Time: 8.72s
# Round 906 | Acc: 76.85% | Sim Time: 8.73s
# Round 907 | Acc: 76.85% | Sim Time: 8.74s
# Round 908 | Acc: 76.90% | Sim Time: 8.75s
# Round 909 | Acc: 76.85% | Sim Time: 8.76s
# Round 910 | Acc: 76.90% | Sim Time: 8.77s
# Round 911 | Acc: 76.85% | Sim Time: 8.78s
# Round 912 | Acc: 76.90% | Sim Time: 8.79s
# Round 913 | Acc: 76.85% | Sim Time: 8.80s
# Round 914 | Acc: 77.00% | Sim Time: 8.81s
# Round 915 | Acc: 77.05% | Sim Time: 8.82s
# Round 916 | Acc: 77.05% | Sim Time: 8.83s
# Round 917 | Acc: 77.05% | Sim Time: 8.84s
# Round 918 | Acc: 77.05% | Sim Time: 8.85s
# Round 919 | Acc: 77.05% | Sim Time: 8.85s
# Round 920 | Acc: 77.15% | Sim Time: 8.86s
# Round 921 | Acc: 77.05% | Sim Time: 8.87s
# Round 922 | Acc: 77.15% | Sim Time: 8.88s
# Round 923 | Acc: 77.05% | Sim Time: 8.89s
# Round 924 | Acc: 77.15% | Sim Time: 8.90s
# Round 925 | Acc: 77.10% | Sim Time: 8.91s
# Round 926 | Acc: 77.20% | Sim Time: 8.92s
# Round 927 | Acc: 77.10% | Sim Time: 8.94s
# Round 928 | Acc: 77.20% | Sim Time: 8.95s
# Round 929 | Acc: 77.15% | Sim Time: 8.96s
# Round 930 | Acc: 77.20% | Sim Time: 8.97s
# Round 931 | Acc: 77.15% | Sim Time: 8.98s
# Round 932 | Acc: 77.05% | Sim Time: 8.98s
# Round 933 | Acc: 77.05% | Sim Time: 8.99s
# Round 934 | Acc: 77.05% | Sim Time: 9.00s
# Round 935 | Acc: 77.05% | Sim Time: 9.01s
# Round 936 | Acc: 77.05% | Sim Time: 9.02s
# Round 937 | Acc: 77.25% | Sim Time: 9.03s
# Round 938 | Acc: 77.05% | Sim Time: 9.04s
# Round 939 | Acc: 77.05% | Sim Time: 9.05s
# Round 940 | Acc: 77.10% | Sim Time: 9.06s
# Round 941 | Acc: 77.05% | Sim Time: 9.07s
# Round 942 | Acc: 77.05% | Sim Time: 9.08s
# Round 943 | Acc: 76.95% | Sim Time: 9.08s
# Round 944 | Acc: 77.00% | Sim Time: 9.09s
# Round 945 | Acc: 76.95% | Sim Time: 9.10s
# Round 946 | Acc: 77.00% | Sim Time: 9.11s
# Round 947 | Acc: 77.00% | Sim Time: 9.11s
# Round 948 | Acc: 77.00% | Sim Time: 9.12s
# Round 949 | Acc: 76.95% | Sim Time: 9.13s
# Round 950 | Acc: 77.00% | Sim Time: 9.14s
# Round 951 | Acc: 76.95% | Sim Time: 9.15s
# Round 952 | Acc: 77.00% | Sim Time: 9.16s
# Round 953 | Acc: 77.00% | Sim Time: 9.17s
# Round 954 | Acc: 77.05% | Sim Time: 9.18s
# Round 955 | Acc: 77.00% | Sim Time: 9.19s
# Round 956 | Acc: 77.05% | Sim Time: 9.20s
# Round 957 | Acc: 76.95% | Sim Time: 9.21s
# Round 958 | Acc: 77.05% | Sim Time: 9.22s
# Round 959 | Acc: 77.00% | Sim Time: 9.23s
# Round 960 | Acc: 77.10% | Sim Time: 9.24s
# Round 961 | Acc: 76.95% | Sim Time: 9.25s
# Round 962 | Acc: 77.00% | Sim Time: 9.26s
# Round 963 | Acc: 77.05% | Sim Time: 9.27s
# Round 964 | Acc: 77.00% | Sim Time: 9.28s
# Round 965 | Acc: 77.05% | Sim Time: 9.29s
# Round 966 | Acc: 77.00% | Sim Time: 9.30s
# Round 967 | Acc: 77.15% | Sim Time: 9.31s
# Round 968 | Acc: 77.20% | Sim Time: 9.32s
# Round 969 | Acc: 77.10% | Sim Time: 9.33s
# Round 970 | Acc: 77.20% | Sim Time: 9.34s
# Round 971 | Acc: 77.15% | Sim Time: 9.35s
# Round 972 | Acc: 77.20% | Sim Time: 9.36s
# Round 973 | Acc: 77.15% | Sim Time: 9.37s
# Round 974 | Acc: 77.20% | Sim Time: 9.38s
# Round 975 | Acc: 77.15% | Sim Time: 9.39s
# Round 976 | Acc: 77.20% | Sim Time: 9.40s
# Round 977 | Acc: 77.30% | Sim Time: 9.41s
# Round 978 | Acc: 77.25% | Sim Time: 9.42s
# Round 979 | Acc: 77.25% | Sim Time: 9.43s
# Round 980 | Acc: 77.30% | Sim Time: 9.44s
# Round 981 | Acc: 77.25% | Sim Time: 9.45s
# Round 982 | Acc: 77.25% | Sim Time: 9.46s
# Round 983 | Acc: 77.20% | Sim Time: 9.47s
# Round 984 | Acc: 77.25% | Sim Time: 9.48s
# Round 985 | Acc: 77.25% | Sim Time: 9.49s
# Round 986 | Acc: 77.25% | Sim Time: 9.50s
# Round 987 | Acc: 77.25% | Sim Time: 9.51s
# Round 988 | Acc: 77.25% | Sim Time: 9.52s
# Round 989 | Acc: 77.20% | Sim Time: 9.53s
# Round 990 | Acc: 77.20% | Sim Time: 9.53s
# Round 991 | Acc: 77.15% | Sim Time: 9.54s
# Round 992 | Acc: 77.10% | Sim Time: 9.55s
# Round 993 | Acc: 77.15% | Sim Time: 9.56s
# Round 994 | Acc: 77.15% | Sim Time: 9.57s
# Round 995 | Acc: 77.25% | Sim Time: 9.58s
# Round 996 | Acc: 77.20% | Sim Time: 9.59s
# Round 997 | Acc: 77.20% | Sim Time: 9.60s
# Round 998 | Acc: 77.20% | Sim Time: 9.61s
# Round 999 | Acc: 77.10% | Sim Time: 9.62s
# Round 1000 | Acc: 77.15% | Sim Time: 9.63s
# Round 1001 | Acc: 77.10% | Sim Time: 9.64s
# Round 1002 | Acc: 77.25% | Sim Time: 9.65s
# Round 1003 | Acc: 77.15% | Sim Time: 9.66s
# Round 1004 | Acc: 77.20% | Sim Time: 9.67s
# Round 1005 | Acc: 77.25% | Sim Time: 9.68s
# Round 1006 | Acc: 77.25% | Sim Time: 9.69s
# Round 1007 | Acc: 77.30% | Sim Time: 9.70s
# Round 1008 | Acc: 77.30% | Sim Time: 9.71s
# Round 1009 | Acc: 77.30% | Sim Time: 9.72s
# Round 1010 | Acc: 77.30% | Sim Time: 9.73s
# Round 1011 | Acc: 77.30% | Sim Time: 9.74s
# Round 1012 | Acc: 77.35% | Sim Time: 9.75s
# Round 1013 | Acc: 77.35% | Sim Time: 9.76s
# Round 1014 | Acc: 77.40% | Sim Time: 9.77s
# Round 1015 | Acc: 77.35% | Sim Time: 9.78s
# Round 1016 | Acc: 77.40% | Sim Time: 9.79s
# Round 1017 | Acc: 77.35% | Sim Time: 9.80s
# Round 1018 | Acc: 77.30% | Sim Time: 9.81s
# Round 1019 | Acc: 77.40% | Sim Time: 9.82s
# Round 1020 | Acc: 77.45% | Sim Time: 9.83s
# Round 1021 | Acc: 77.45% | Sim Time: 9.84s
# Round 1022 | Acc: 77.50% | Sim Time: 9.85s
# Round 1023 | Acc: 77.35% | Sim Time: 9.86s
# Round 1024 | Acc: 77.50% | Sim Time: 9.87s
# Round 1025 | Acc: 77.50% | Sim Time: 9.88s
# Round 1026 | Acc: 77.50% | Sim Time: 9.89s
# Round 1027 | Acc: 77.50% | Sim Time: 9.89s
# Round 1028 | Acc: 77.35% | Sim Time: 9.90s
# Round 1029 | Acc: 77.55% | Sim Time: 9.91s
# Round 1030 | Acc: 77.50% | Sim Time: 9.92s
# Round 1031 | Acc: 77.45% | Sim Time: 9.94s
# Round 1032 | Acc: 77.40% | Sim Time: 9.95s
# Round 1033 | Acc: 77.45% | Sim Time: 9.96s
# Round 1034 | Acc: 77.40% | Sim Time: 9.97s
# Round 1035 | Acc: 77.50% | Sim Time: 9.98s
# Round 1036 | Acc: 77.55% | Sim Time: 9.99s
# Round 1037 | Acc: 77.55% | Sim Time: 10.00s
# Round 1038 | Acc: 77.55% | Sim Time: 10.01s
# Round 1039 | Acc: 77.50% | Sim Time: 10.02s
# Round 1040 | Acc: 77.55% | Sim Time: 10.03s
# Round 1041 | Acc: 77.60% | Sim Time: 10.04s
# Round 1042 | Acc: 77.55% | Sim Time: 10.05s
# Round 1043 | Acc: 77.55% | Sim Time: 10.06s
# Round 1044 | Acc: 77.55% | Sim Time: 10.07s
# Round 1045 | Acc: 77.55% | Sim Time: 10.08s
# Round 1046 | Acc: 77.55% | Sim Time: 10.08s
# Round 1047 | Acc: 77.55% | Sim Time: 10.09s
# Round 1048 | Acc: 77.55% | Sim Time: 10.10s
# Round 1049 | Acc: 77.55% | Sim Time: 10.11s
# Round 1050 | Acc: 77.55% | Sim Time: 10.11s
# Round 1051 | Acc: 77.65% | Sim Time: 10.12s
# Round 1052 | Acc: 77.55% | Sim Time: 10.13s
# Round 1053 | Acc: 77.55% | Sim Time: 10.14s
# Round 1054 | Acc: 77.60% | Sim Time: 10.15s
# Round 1055 | Acc: 77.70% | Sim Time: 10.16s
# Round 1056 | Acc: 77.70% | Sim Time: 10.17s
# Round 1057 | Acc: 77.65% | Sim Time: 10.18s
# Round 1058 | Acc: 77.55% | Sim Time: 10.19s
# Round 1059 | Acc: 77.65% | Sim Time: 10.20s
# Round 1060 | Acc: 77.65% | Sim Time: 10.21s
# Round 1061 | Acc: 77.65% | Sim Time: 10.22s
# Round 1062 | Acc: 77.65% | Sim Time: 10.23s
# Round 1063 | Acc: 77.60% | Sim Time: 10.23s
# Round 1064 | Acc: 77.55% | Sim Time: 10.24s
# Round 1065 | Acc: 77.55% | Sim Time: 10.25s
# Round 1066 | Acc: 77.65% | Sim Time: 10.26s
# Round 1067 | Acc: 77.55% | Sim Time: 10.27s
# Round 1068 | Acc: 77.55% | Sim Time: 10.28s
# Round 1069 | Acc: 77.50% | Sim Time: 10.30s
# Round 1070 | Acc: 77.55% | Sim Time: 10.31s
# Round 1071 | Acc: 77.60% | Sim Time: 10.32s
# Round 1072 | Acc: 77.65% | Sim Time: 10.33s
# Round 1073 | Acc: 77.60% | Sim Time: 10.34s
# Round 1074 | Acc: 77.55% | Sim Time: 10.34s
# Round 1075 | Acc: 77.55% | Sim Time: 10.35s
# Round 1076 | Acc: 77.60% | Sim Time: 10.36s
# Round 1077 | Acc: 77.65% | Sim Time: 10.37s
# Round 1078 | Acc: 77.70% | Sim Time: 10.38s
# Round 1079 | Acc: 77.75% | Sim Time: 10.39s
# Round 1080 | Acc: 77.65% | Sim Time: 10.40s
# Round 1081 | Acc: 77.60% | Sim Time: 10.41s
# Round 1082 | Acc: 77.65% | Sim Time: 10.42s
# Round 1083 | Acc: 77.65% | Sim Time: 10.43s
# Round 1084 | Acc: 77.65% | Sim Time: 10.44s
# Round 1085 | Acc: 77.65% | Sim Time: 10.45s
# Round 1086 | Acc: 77.65% | Sim Time: 10.46s
# Round 1087 | Acc: 77.55% | Sim Time: 10.47s
# Round 1088 | Acc: 77.50% | Sim Time: 10.48s
# Round 1089 | Acc: 77.60% | Sim Time: 10.49s
# Round 1090 | Acc: 77.45% | Sim Time: 10.50s
# Round 1091 | Acc: 77.60% | Sim Time: 10.51s
# Round 1092 | Acc: 77.60% | Sim Time: 10.52s
# Round 1093 | Acc: 77.55% | Sim Time: 10.53s
# Round 1094 | Acc: 77.65% | Sim Time: 10.54s
# Round 1095 | Acc: 77.65% | Sim Time: 10.55s
# Round 1096 | Acc: 77.65% | Sim Time: 10.56s
# Round 1097 | Acc: 77.75% | Sim Time: 10.57s
# Round 1098 | Acc: 77.65% | Sim Time: 10.58s
# Round 1099 | Acc: 77.65% | Sim Time: 10.59s
# Round 1100 | Acc: 77.70% | Sim Time: 10.59s
# Round 1101 | Acc: 77.75% | Sim Time: 10.60s
# Round 1102 | Acc: 77.70% | Sim Time: 10.61s
# Round 1103 | Acc: 77.75% | Sim Time: 10.62s
# Round 1104 | Acc: 77.70% | Sim Time: 10.63s
# Round 1105 | Acc: 77.75% | Sim Time: 10.64s
# Round 1106 | Acc: 77.70% | Sim Time: 10.65s
# Round 1107 | Acc: 77.75% | Sim Time: 10.66s
# Round 1108 | Acc: 77.75% | Sim Time: 10.67s
# Round 1109 | Acc: 77.70% | Sim Time: 10.68s
# Round 1110 | Acc: 77.75% | Sim Time: 10.69s
# Round 1111 | Acc: 77.75% | Sim Time: 10.70s
# Round 1112 | Acc: 77.70% | Sim Time: 10.71s
# Round 1113 | Acc: 77.75% | Sim Time: 10.72s
# Round 1114 | Acc: 77.70% | Sim Time: 10.73s
# Round 1115 | Acc: 77.75% | Sim Time: 10.74s
# Round 1116 | Acc: 77.75% | Sim Time: 10.75s
# Round 1117 | Acc: 77.75% | Sim Time: 10.76s
# Round 1118 | Acc: 77.75% | Sim Time: 10.77s
# Round 1119 | Acc: 77.75% | Sim Time: 10.78s
# Round 1120 | Acc: 77.80% | Sim Time: 10.79s
# Round 1121 | Acc: 77.80% | Sim Time: 10.80s
# Round 1122 | Acc: 77.85% | Sim Time: 10.81s
# Round 1123 | Acc: 77.80% | Sim Time: 10.82s
# Round 1124 | Acc: 77.85% | Sim Time: 10.83s
# Round 1125 | Acc: 77.90% | Sim Time: 10.84s
# Round 1126 | Acc: 77.90% | Sim Time: 10.85s
# Round 1127 | Acc: 77.90% | Sim Time: 10.86s
# Round 1128 | Acc: 77.95% | Sim Time: 10.87s
# Round 1129 | Acc: 77.95% | Sim Time: 10.88s
# Round 1130 | Acc: 77.95% | Sim Time: 10.89s
# Round 1131 | Acc: 77.95% | Sim Time: 10.90s
# Round 1132 | Acc: 77.95% | Sim Time: 10.91s
# Round 1133 | Acc: 77.95% | Sim Time: 10.92s
# Round 1134 | Acc: 77.75% | Sim Time: 10.93s
# Round 1135 | Acc: 77.90% | Sim Time: 10.94s
# Round 1136 | Acc: 77.95% | Sim Time: 10.95s
# ...
# Round 11654 | Acc: 82.05% | Sim Time: 105.82s
# Round 11655 | Acc: 82.05% | Sim Time: 105.83s
# Round 11656 | Acc: 82.05% | Sim Time: 105.84s
# Round 11657 | Acc: 82.00% | Sim Time: 105.84s
# Round 11658 | Acc: 82.00% | Sim Time: 105.85s
# Round 11659 | Acc: 82.05% | Sim Time: 105.86s
# Round 11660 | Acc: 82.00% | Sim Time: 105.87s
# Round 11661 | Acc: 82.00% | Sim Time: 105.88s
# Round 11662 | Acc: 82.00% | Sim Time: 105.89s
# Round 11663 | Acc: 82.00% | Sim Time: 105.89s
# Round 11664 | Acc: 82.05% | Sim Time: 105.90s
# Round 11665 | Acc: 82.00% | Sim Time: 105.91s
# Round 11666 | Acc: 82.00% | Sim Time: 105.92s
# Round 11667 | Acc: 82.00% | Sim Time: 105.93s
# Round 11668 | Acc: 82.00% | Sim Time: 105.94s
# Round 11669 | Acc: 82.00% | Sim Time: 105.95s
# Round 11670 | Acc: 82.00% | Sim Time: 105.96s
# Round 11671 | Acc: 82.05% | Sim Time: 105.97s
# Round 11672 | Acc: 82.00% | Sim Time: 105.98s
# Round 11673 | Acc: 82.05% | Sim Time: 105.99s
# Round 11674 | Acc: 82.05% | Sim Time: 105.99s
# Round 11675 | Acc: 82.00% | Sim Time: 106.00s
# Round 11676 | Acc: 82.00% | Sim Time: 106.02s
# Round 11677 | Acc: 82.00% | Sim Time: 106.02s
# Round 11678 | Acc: 82.00% | Sim Time: 106.03s
# Round 11679 | Acc: 82.00% | Sim Time: 106.04s
# Round 11680 | Acc: 82.00% | Sim Time: 106.05s
# Round 11681 | Acc: 82.00% | Sim Time: 106.06s
# Round 11682 | Acc: 82.00% | Sim Time: 106.06s
# Round 11683 | Acc: 82.00% | Sim Time: 106.08s
# Round 11684 | Acc: 82.00% | Sim Time: 106.09s
# Round 11685 | Acc: 82.05% | Sim Time: 106.10s
# Round 11686 | Acc: 82.00% | Sim Time: 106.10s
# Round 11687 | Acc: 82.00% | Sim Time: 106.11s
# Round 11688 | Acc: 82.00% | Sim Time: 106.12s
# Round 11689 | Acc: 82.00% | Sim Time: 106.13s
# Round 11690 | Acc: 82.00% | Sim Time: 106.14s
# Round 11691 | Acc: 82.00% | Sim Time: 106.15s
# Round 11692 | Acc: 81.95% | Sim Time: 106.16s
# Round 11693 | Acc: 81.95% | Sim Time: 106.17s
# Round 11694 | Acc: 81.95% | Sim Time: 106.18s
# Round 11695 | Acc: 81.85% | Sim Time: 106.19s
# Round 11696 | Acc: 81.80% | Sim Time: 106.20s
# Round 11697 | Acc: 81.85% | Sim Time: 106.20s
# Round 11698 | Acc: 81.90% | Sim Time: 106.21s
# Round 11699 | Acc: 81.90% | Sim Time: 106.22s
# Round 11700 | Acc: 81.90% | Sim Time: 106.23s
# Round 11701 | Acc: 81.95% | Sim Time: 106.24s
# Round 11702 | Acc: 82.00% | Sim Time: 106.25s
# Round 11703 | Acc: 82.00% | Sim Time: 106.26s
# Round 11704 | Acc: 82.00% | Sim Time: 106.27s
# Round 11705 | Acc: 81.95% | Sim Time: 106.27s
# Round 11706 | Acc: 81.95% | Sim Time: 106.28s
# Round 11707 | Acc: 81.95% | Sim Time: 106.29s
# Round 11708 | Acc: 81.95% | Sim Time: 106.30s
# Round 11709 | Acc: 81.95% | Sim Time: 106.31s
# Round 11710 | Acc: 81.95% | Sim Time: 106.32s
# Round 11711 | Acc: 81.80% | Sim Time: 106.32s
# Round 11712 | Acc: 81.80% | Sim Time: 106.33s
# Round 11713 | Acc: 81.90% | Sim Time: 106.34s
# Round 11714 | Acc: 81.90% | Sim Time: 106.35s
# Round 11715 | Acc: 81.90% | Sim Time: 106.36s
# Round 11716 | Acc: 81.85% | Sim Time: 106.37s
# Round 11717 | Acc: 81.95% | Sim Time: 106.38s
# Round 11718 | Acc: 81.90% | Sim Time: 106.39s
# Round 11719 | Acc: 81.95% | Sim Time: 106.40s
# Round 11720 | Acc: 81.90% | Sim Time: 106.41s
# Round 11721 | Acc: 81.90% | Sim Time: 106.42s
# Round 11722 | Acc: 81.85% | Sim Time: 106.43s
# Round 11723 | Acc: 81.85% | Sim Time: 106.44s
# Round 11724 | Acc: 81.85% | Sim Time: 106.45s
# Round 11725 | Acc: 81.85% | Sim Time: 106.46s
# Round 11726 | Acc: 81.85% | Sim Time: 106.46s
# Round 11727 | Acc: 81.90% | Sim Time: 106.47s
# Round 11728 | Acc: 81.90% | Sim Time: 106.48s
# Round 11729 | Acc: 81.85% | Sim Time: 106.49s
# Round 11730 | Acc: 81.90% | Sim Time: 106.50s
# Round 11731 | Acc: 81.85% | Sim Time: 106.51s
# Round 11732 | Acc: 81.90% | Sim Time: 106.52s
# Round 11733 | Acc: 81.85% | Sim Time: 106.52s
# Round 11734 | Acc: 81.85% | Sim Time: 106.53s
# Round 11735 | Acc: 81.85% | Sim Time: 106.54s
# Round 11736 | Acc: 81.90% | Sim Time: 106.55s
# Round 11737 | Acc: 81.90% | Sim Time: 106.56s
# Round 11738 | Acc: 81.90% | Sim Time: 106.57s
# Round 11739 | Acc: 81.90% | Sim Time: 106.58s
# Round 11740 | Acc: 81.90% | Sim Time: 106.58s
# Round 11741 | Acc: 81.90% | Sim Time: 106.59s
# Round 11742 | Acc: 81.90% | Sim Time: 106.60s
# Round 11743 | Acc: 81.90% | Sim Time: 106.61s
# Round 11744 | Acc: 81.90% | Sim Time: 106.62s
# Round 11745 | Acc: 81.90% | Sim Time: 106.63s
# Round 11746 | Acc: 81.90% | Sim Time: 106.64s
# Round 11747 | Acc: 81.85% | Sim Time: 106.65s
# Round 11748 | Acc: 81.85% | Sim Time: 106.66s
# Round 11749 | Acc: 81.90% | Sim Time: 106.67s
# Round 11750 | Acc: 81.90% | Sim Time: 106.68s
# Round 11751 | Acc: 81.85% | Sim Time: 106.68s
# Round 11752 | Acc: 81.90% | Sim Time: 106.69s
# Round 11753 | Acc: 81.85% | Sim Time: 106.71s
# Round 11754 | Acc: 81.90% | Sim Time: 106.71s
# Round 11755 | Acc: 81.90% | Sim Time: 106.73s
# Round 11756 | Acc: 81.90% | Sim Time: 106.74s
# Round 11757 | Acc: 81.90% | Sim Time: 106.74s
# Round 11758 | Acc: 81.90% | Sim Time: 106.75s
# Round 11759 | Acc: 81.90% | Sim Time: 106.76s
# Round 11760 | Acc: 81.90% | Sim Time: 106.77s
# Round 11761 | Acc: 81.90% | Sim Time: 106.77s
# Round 11762 | Acc: 82.00% | Sim Time: 106.79s
# Round 11763 | Acc: 82.00% | Sim Time: 106.79s
# Round 11764 | Acc: 81.95% | Sim Time: 106.80s
# Round 11765 | Acc: 81.95% | Sim Time: 106.81s
# Round 11766 | Acc: 81.95% | Sim Time: 106.82s
# Round 11767 | Acc: 81.95% | Sim Time: 106.83s
# Round 11768 | Acc: 81.95% | Sim Time: 106.84s
# Round 11769 | Acc: 81.95% | Sim Time: 106.85s
# Round 11770 | Acc: 81.95% | Sim Time: 106.86s
# Round 11771 | Acc: 81.95% | Sim Time: 106.87s
# Round 11772 | Acc: 81.95% | Sim Time: 106.87s
# Round 11773 | Acc: 81.95% | Sim Time: 106.88s
# Round 11774 | Acc: 81.95% | Sim Time: 106.89s
# Round 11775 | Acc: 81.95% | Sim Time: 106.90s
# Round 11776 | Acc: 81.95% | Sim Time: 106.91s
# Round 11777 | Acc: 81.95% | Sim Time: 106.92s
# Round 11778 | Acc: 81.95% | Sim Time: 106.92s
# Round 11779 | Acc: 81.95% | Sim Time: 106.93s
# Round 11780 | Acc: 81.95% | Sim Time: 106.94s
# Round 11781 | Acc: 81.95% | Sim Time: 106.95s
# Round 11782 | Acc: 81.95% | Sim Time: 106.96s
# Round 11783 | Acc: 81.95% | Sim Time: 106.97s
# Round 11784 | Acc: 81.95% | Sim Time: 106.97s
# Round 11785 | Acc: 81.95% | Sim Time: 106.98s
# Round 11786 | Acc: 81.95% | Sim Time: 107.00s
# Round 11787 | Acc: 82.00% | Sim Time: 107.01s
# Round 11788 | Acc: 81.95% | Sim Time: 107.02s
# Round 11789 | Acc: 81.95% | Sim Time: 107.03s
# Round 11790 | Acc: 81.95% | Sim Time: 107.03s
# Round 11791 | Acc: 81.95% | Sim Time: 107.04s
# Round 11792 | Acc: 81.95% | Sim Time: 107.05s
# Round 11793 | Acc: 81.95% | Sim Time: 107.06s
# Round 11794 | Acc: 81.95% | Sim Time: 107.07s
# Round 11795 | Acc: 81.95% | Sim Time: 107.08s
# Round 11796 | Acc: 81.95% | Sim Time: 107.08s
# Round 11797 | Acc: 81.95% | Sim Time: 107.09s
# Round 11798 | Acc: 81.95% | Sim Time: 107.10s
# Round 11799 | Acc: 81.95% | Sim Time: 107.11s
# Round 11800 | Acc: 81.95% | Sim Time: 107.12s
# Round 11801 | Acc: 81.95% | Sim Time: 107.13s
# Round 11802 | Acc: 81.95% | Sim Time: 107.14s
# Round 11803 | Acc: 81.95% | Sim Time: 107.15s
# Round 11804 | Acc: 81.95% | Sim Time: 107.15s
# Round 11805 | Acc: 81.95% | Sim Time: 107.16s
# Round 11806 | Acc: 81.95% | Sim Time: 107.17s
# Round 11807 | Acc: 81.95% | Sim Time: 107.18s
# Round 11808 | Acc: 81.95% | Sim Time: 107.19s
# Round 11809 | Acc: 81.95% | Sim Time: 107.20s
# Round 11810 | Acc: 81.95% | Sim Time: 107.21s
# Round 11811 | Acc: 82.00% | Sim Time: 107.22s
# Round 11812 | Acc: 82.00% | Sim Time: 107.23s
# Round 11813 | Acc: 81.95% | Sim Time: 107.24s
# Round 11814 | Acc: 81.95% | Sim Time: 107.24s
# Round 11815 | Acc: 82.00% | Sim Time: 107.25s
# Round 11816 | Acc: 82.00% | Sim Time: 107.26s
# Round 11817 | Acc: 82.00% | Sim Time: 107.27s
# Round 11818 | Acc: 82.00% | Sim Time: 107.28s
# Round 11819 | Acc: 81.95% | Sim Time: 107.29s
# Round 11820 | Acc: 81.95% | Sim Time: 107.30s
# Round 11821 | Acc: 81.90% | Sim Time: 107.31s
# Round 11822 | Acc: 81.95% | Sim Time: 107.32s
# Round 11823 | Acc: 82.00% | Sim Time: 107.33s
# Round 11824 | Acc: 81.95% | Sim Time: 107.34s
# Round 11825 | Acc: 81.90% | Sim Time: 107.35s
# Round 11826 | Acc: 81.95% | Sim Time: 107.36s
# Round 11827 | Acc: 82.00% | Sim Time: 107.36s
# Round 11828 | Acc: 81.95% | Sim Time: 107.37s
# Round 11829 | Acc: 81.95% | Sim Time: 107.38s
# Round 11830 | Acc: 81.95% | Sim Time: 107.39s
# Round 11831 | Acc: 82.00% | Sim Time: 107.40s
# Round 11832 | Acc: 82.00% | Sim Time: 107.40s
# Round 11833 | Acc: 82.00% | Sim Time: 107.41s
# Round 11834 | Acc: 82.00% | Sim Time: 107.42s
# Round 11835 | Acc: 81.95% | Sim Time: 107.43s
# Round 11836 | Acc: 81.95% | Sim Time: 107.44s
# Round 11837 | Acc: 81.95% | Sim Time: 107.45s
# Round 11838 | Acc: 81.95% | Sim Time: 107.46s
# Round 11839 | Acc: 81.95% | Sim Time: 107.47s
# Round 11840 | Acc: 81.95% | Sim Time: 107.48s
# Round 11841 | Acc: 82.00% | Sim Time: 107.49s
# Round 11842 | Acc: 81.95% | Sim Time: 107.50s
# Round 11843 | Acc: 81.95% | Sim Time: 107.51s
# Round 11844 | Acc: 81.95% | Sim Time: 107.52s
# Round 11845 | Acc: 82.00% | Sim Time: 107.53s
# Round 11846 | Acc: 82.00% | Sim Time: 107.53s
# Round 11847 | Acc: 82.00% | Sim Time: 107.54s
# Round 11848 | Acc: 82.00% | Sim Time: 107.55s
# Round 11849 | Acc: 82.00% | Sim Time: 107.56s
# Round 11850 | Acc: 81.95% | Sim Time: 107.57s
# Round 11851 | Acc: 81.95% | Sim Time: 107.58s
# Round 11852 | Acc: 81.95% | Sim Time: 107.59s
# Round 11853 | Acc: 81.90% | Sim Time: 107.60s
# Round 11854 | Acc: 81.95% | Sim Time: 107.61s
# Round 11855 | Acc: 81.90% | Sim Time: 107.62s
# Round 11856 | Acc: 81.95% | Sim Time: 107.63s
# Round 11857 | Acc: 81.95% | Sim Time: 107.64s
# Round 11858 | Acc: 81.95% | Sim Time: 107.65s
# Round 11859 | Acc: 81.95% | Sim Time: 107.66s
# Round 11860 | Acc: 82.00% | Sim Time: 107.67s
# Round 11861 | Acc: 81.95% | Sim Time: 107.67s
# Round 11862 | Acc: 81.95% | Sim Time: 107.68s
# Round 11863 | Acc: 81.95% | Sim Time: 107.69s
# Round 11864 | Acc: 81.95% | Sim Time: 107.70s
# Round 11865 | Acc: 81.95% | Sim Time: 107.71s
# Round 11866 | Acc: 81.90% | Sim Time: 107.72s
# Round 11867 | Acc: 81.95% | Sim Time: 107.73s
# Round 11868 | Acc: 82.00% | Sim Time: 107.74s
# Round 11869 | Acc: 81.95% | Sim Time: 107.75s
# Round 11870 | Acc: 81.95% | Sim Time: 107.76s
# Round 11871 | Acc: 81.90% | Sim Time: 107.77s
# Round 11872 | Acc: 81.90% | Sim Time: 107.78s
# Round 11873 | Acc: 81.90% | Sim Time: 107.78s
# Round 11874 | Acc: 81.90% | Sim Time: 107.79s
# Round 11875 | Acc: 82.00% | Sim Time: 107.80s
# Round 11876 | Acc: 82.00% | Sim Time: 107.81s
# Round 11877 | Acc: 81.95% | Sim Time: 107.82s
# Round 11878 | Acc: 82.00% | Sim Time: 107.83s
# Round 11879 | Acc: 82.00% | Sim Time: 107.84s
# Round 11880 | Acc: 82.00% | Sim Time: 107.84s
# Round 11881 | Acc: 82.00% | Sim Time: 107.85s
# Round 11882 | Acc: 82.05% | Sim Time: 107.86s
# Round 11883 | Acc: 82.05% | Sim Time: 107.87s
# Round 11884 | Acc: 82.00% | Sim Time: 107.88s
# Round 11885 | Acc: 82.05% | Sim Time: 107.89s
# Round 11886 | Acc: 82.00% | Sim Time: 107.90s
# Round 11887 | Acc: 82.05% | Sim Time: 107.91s
# Round 11888 | Acc: 82.00% | Sim Time: 107.92s
# Round 11889 | Acc: 82.05% | Sim Time: 107.92s
# Round 11890 | Acc: 82.00% | Sim Time: 107.93s
# Round 11891 | Acc: 81.90% | Sim Time: 107.94s
# Round 11892 | Acc: 82.05% | Sim Time: 107.95s
# Round 11893 | Acc: 81.90% | Sim Time: 107.96s
# Round 11894 | Acc: 81.85% | Sim Time: 107.97s
# Round 11895 | Acc: 81.85% | Sim Time: 107.98s
# Round 11896 | Acc: 81.85% | Sim Time: 107.99s
# Round 11897 | Acc: 81.90% | Sim Time: 108.00s
# Round 11898 | Acc: 81.90% | Sim Time: 108.01s
# Round 11899 | Acc: 81.85% | Sim Time: 108.02s
# Round 11900 | Acc: 81.90% | Sim Time: 108.03s
# Round 11901 | Acc: 81.90% | Sim Time: 108.04s
# Round 11902 | Acc: 81.90% | Sim Time: 108.04s
# Round 11903 | Acc: 81.90% | Sim Time: 108.05s
# Round 11904 | Acc: 81.95% | Sim Time: 108.06s
# Round 11905 | Acc: 81.85% | Sim Time: 108.07s
# Round 11906 | Acc: 81.90% | Sim Time: 108.08s
# Round 11907 | Acc: 81.90% | Sim Time: 108.08s
# Round 11908 | Acc: 81.90% | Sim Time: 108.09s
# Round 11909 | Acc: 81.90% | Sim Time: 108.10s
# Round 11910 | Acc: 82.00% | Sim Time: 108.11s
# Round 11911 | Acc: 81.95% | Sim Time: 108.12s
# Round 11912 | Acc: 82.00% | Sim Time: 108.13s
# Round 11913 | Acc: 81.95% | Sim Time: 108.14s
# Round 11914 | Acc: 81.95% | Sim Time: 108.15s
# Round 11915 | Acc: 82.00% | Sim Time: 108.15s
# Round 11916 | Acc: 81.90% | Sim Time: 108.16s
# Round 11917 | Acc: 81.90% | Sim Time: 108.17s
# Round 11918 | Acc: 81.90% | Sim Time: 108.18s
# Round 11919 | Acc: 81.90% | Sim Time: 108.19s
# Round 11920 | Acc: 81.95% | Sim Time: 108.20s
# Round 11921 | Acc: 81.90% | Sim Time: 108.20s
# Round 11922 | Acc: 81.90% | Sim Time: 108.21s
# Round 11923 | Acc: 81.90% | Sim Time: 108.22s
# Round 11924 | Acc: 81.95% | Sim Time: 108.23s
# Round 11925 | Acc: 81.85% | Sim Time: 108.24s
# Round 11926 | Acc: 81.90% | Sim Time: 108.25s
# Round 11927 | Acc: 81.90% | Sim Time: 108.26s
# Round 11928 | Acc: 81.90% | Sim Time: 108.27s
# Round 11929 | Acc: 81.90% | Sim Time: 108.28s
# Round 11930 | Acc: 82.00% | Sim Time: 108.29s
# Round 11931 | Acc: 82.05% | Sim Time: 108.30s
# Round 11932 | Acc: 82.00% | Sim Time: 108.31s
# Round 11933 | Acc: 82.00% | Sim Time: 108.31s
# Round 11934 | Acc: 82.00% | Sim Time: 108.32s
# Round 11935 | Acc: 82.00% | Sim Time: 108.34s
# Round 11936 | Acc: 82.00% | Sim Time: 108.35s
# Round 11937 | Acc: 82.00% | Sim Time: 108.35s
# Round 11938 | Acc: 82.00% | Sim Time: 108.36s
# Round 11939 | Acc: 82.00% | Sim Time: 108.37s
# Round 11940 | Acc: 82.05% | Sim Time: 108.38s
# Round 11941 | Acc: 82.00% | Sim Time: 108.39s
# Round 11942 | Acc: 82.00% | Sim Time: 108.40s
# Round 11943 | Acc: 82.00% | Sim Time: 108.41s
# Round 11944 | Acc: 82.00% | Sim Time: 108.42s
# Round 11945 | Acc: 82.00% | Sim Time: 108.42s
# Round 11946 | Acc: 82.00% | Sim Time: 108.43s
# Round 11947 | Acc: 82.00% | Sim Time: 108.44s
# Round 11948 | Acc: 82.00% | Sim Time: 108.45s
# Round 11949 | Acc: 82.05% | Sim Time: 108.46s
# Round 11950 | Acc: 82.00% | Sim Time: 108.47s
# Round 11951 | Acc: 81.95% | Sim Time: 108.48s
# Round 11952 | Acc: 82.00% | Sim Time: 108.49s
# Round 11953 | Acc: 82.00% | Sim Time: 108.50s
# Round 11954 | Acc: 82.00% | Sim Time: 108.50s
# Round 11955 | Acc: 82.00% | Sim Time: 108.51s
# Round 11956 | Acc: 82.00% | Sim Time: 108.52s
# Round 11957 | Acc: 82.05% | Sim Time: 108.53s
# Round 11958 | Acc: 82.00% | Sim Time: 108.54s
# Round 11959 | Acc: 82.05% | Sim Time: 108.55s
# Round 11960 | Acc: 82.05% | Sim Time: 108.56s
# Round 11961 | Acc: 82.00% | Sim Time: 108.57s
# Round 11962 | Acc: 81.90% | Sim Time: 108.58s
# Round 11963 | Acc: 82.00% | Sim Time: 108.59s
# Round 11964 | Acc: 82.00% | Sim Time: 108.59s
# Round 11965 | Acc: 82.05% | Sim Time: 108.60s
# Round 11966 | Acc: 82.00% | Sim Time: 108.61s
# Round 11967 | Acc: 82.05% | Sim Time: 108.62s
# Round 11968 | Acc: 82.00% | Sim Time: 108.63s
# Round 11969 | Acc: 82.00% | Sim Time: 108.63s
# Round 11970 | Acc: 82.00% | Sim Time: 108.64s
# Round 11971 | Acc: 81.90% | Sim Time: 108.65s
# Round 11972 | Acc: 81.90% | Sim Time: 108.66s
# Round 11973 | Acc: 81.95% | Sim Time: 108.67s
# Round 11974 | Acc: 81.95% | Sim Time: 108.68s
# Round 11975 | Acc: 81.90% | Sim Time: 108.69s
# Round 11976 | Acc: 81.95% | Sim Time: 108.70s
# Round 11977 | Acc: 81.95% | Sim Time: 108.71s
# Round 11978 | Acc: 81.95% | Sim Time: 108.72s
# Round 11979 | Acc: 81.95% | Sim Time: 108.72s
# Round 11980 | Acc: 81.95% | Sim Time: 108.73s
# Round 11981 | Acc: 82.05% | Sim Time: 108.74s
# Round 11982 | Acc: 82.05% | Sim Time: 108.75s
# Round 11983 | Acc: 82.00% | Sim Time: 108.76s
# Round 11984 | Acc: 82.05% | Sim Time: 108.77s
# Round 11985 | Acc: 82.00% | Sim Time: 108.78s
# Round 11986 | Acc: 82.05% | Sim Time: 108.79s
# Round 11987 | Acc: 82.05% | Sim Time: 108.80s
# Round 11988 | Acc: 82.05% | Sim Time: 108.81s
# Round 11989 | Acc: 82.05% | Sim Time: 108.82s
# Round 11990 | Acc: 82.05% | Sim Time: 108.83s
# Round 11991 | Acc: 82.05% | Sim Time: 108.83s
# Round 11992 | Acc: 81.95% | Sim Time: 108.84s
# Round 11993 | Acc: 81.95% | Sim Time: 108.85s
# Round 11994 | Acc: 81.90% | Sim Time: 108.86s
# Round 11995 | Acc: 81.90% | Sim Time: 108.87s
# Round 11996 | Acc: 81.90% | Sim Time: 108.88s
# Round 11997 | Acc: 82.05% | Sim Time: 108.88s
# Round 11998 | Acc: 82.10% | Sim Time: 108.89s
# Round 11999 | Acc: 82.10% | Sim Time: 108.90s
# Round 12000 | Acc: 81.90% | Sim Time: 108.91s
